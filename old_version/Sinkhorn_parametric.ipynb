# %%
import numpy as np
import matplotlib
#matplotlib.use('Agg')

import matplotlib.pyplot as plt
import pickle as pkl

from torch.utils.data import Dataset, DataLoader
from torch.nn import Linear, ReLU, Module
from torch.nn.init import kaiming_uniform_, xavier_uniform_
import torch.nn as nn

np.random.seed(0)

import torch
import geomloss

# %%
DIM = 64 # Model dimensionality (number of neurons in the hidden layer(s))
CRITIC_ITERS = 5 # How many critic iterations (Sinkhorn iterations) per generator iteration#was 50
BATCH_SIZE = 256 # Batch size
EPOCHS = 10#55#100000 # how many generator iterations to train for
DATA_DIM = 32
LATENT_DIM = 8
INITIALIZATION = 'he'#'glorot'
COVARIANCE_SCALE = np.sqrt(DATA_DIM)
INITIALIZE_LAST = True
SAMPLE_SIZE = 100000
LAMBDA = .5#2/(COVARIANCE_SCALE)
MODE = 'divergence' #'loss', 'wgan-wc', 'wgan-gp'
PARAMETRIC = True

# %%
def initializer(weight):
    if INITIALIZATION == 'he':
        return kaiming_uniform_(weight, nonlinearity='relu')
    if INITIALIZATION == 'glorot':
        return xavier_uniform_(weight)
    print("UNKNOWN INITIALIZATION")
    return None

def init_weights(m):
    if type(m) == nn.Linear:
        initializer(m.weight)

# %%
class GaussianDataset(Dataset):
    # reading the csv and defining predictor and output columns
    def __init__(self, sample_size=SAMPLE_SIZE, data_dim=DATA_DIM, latent_dim = LATENT_DIM,
                 variance = 1/COVARIANCE_SCALE):
    
        # store the input and output features
        
        np.random.seed(1)
        self.X = np.random.randn(sample_size,data_dim) * np.sqrt(variance)
        self.latent_dim = latent_dim
    
        # ensure all data is numerical - type(float)
        self.X = self.X.astype('float32')
    
    # number of rows in dataset
    def __len__(self):
        return len(self.X)
    
    # get a row at an index
    def __getitem__(self, index):
        return [np.random.randn(self.latent_dim).astype('float32'), self.X[index], 
                np.random.randn(self.latent_dim).astype('float32'), 
                np.random.randn(self.latent_dim).astype('float32')]
dataset = GaussianDataset()
data_dl = DataLoader(dataset, batch_size = BATCH_SIZE, shuffle = True)

# %%
class Generator(Module):
    def __init__(self, n_inputs = LATENT_DIM):
        super(Generator, self).__init__()

        self.model = nn.Sequential(        
        # defining the inputs to the first hidden layer
            Linear(n_inputs, DIM) ,
            ReLU(),
            Linear(DIM, DIM),
            ReLU(),
            Linear(DIM, DIM),
            ReLU(),
            Linear(DIM, DATA_DIM),
        )
        self.model.apply(init_weights)

    def forward(self, X):
        X = self.model(X)
        return X

class Discriminator(Module):
    def __init__(self, n_inputs = DATA_DIM):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(        
        # defining the inputs to the first hidden layer
            Linear(n_inputs, DIM) ,
            ReLU(),
            Linear(DIM, DIM),
            ReLU(),
            Linear(DIM, DIM),
            ReLU(),
            Linear(DIM, 1),
        )
        self.model.apply(init_weights)

    def forward(self, X):
        X = self.model(X)
        return X
    
class SGAN(Module):
    def __init__(self, n_inputs = LATENT_DIM, n_):
        super(SGAN, self).__init__()

        self.model = nn.Sequential(        
        # defining the inputs to the first hidden layer
            Linear(n_inputs, DIM) ,
            ReLU(),
            Linear(DIM, DIM),
            ReLU(),
            Linear(DIM, DIM),
            ReLU(),
            Linear(DIM, 1),
        )
        self.model.apply(init_weights)

    def forward(self, X):
        X = self.model(X)
        return X

# %%
# Initialize generator and discriminator and optimizers
generator = Generator()
optimizer_G = torch.optim.Adam(generator.parameters(), lr = 0.003)



if PARAMETRIC or (MODE in ['wgan-wc', 'wgan-gp']):
    discriminator_fake = Discriminator() #for fake data (hat_Y) in W(Y, hat_Y)
    optimizer_Df = torch.optim.RMSprop(discriminator_fake.parameters(),lr=0.005)
    optimizers_disc = [optimizer_Df] #discriminator optimizers
    
    if MODE == 'divergence':
        discriminator_real = Discriminator() #for real data (Y) in W(Y, hat_Y)
        optimizer_Dr = torch.optim.RMSprop(discriminator_real.parameters(),lr=0.005)
        optimizers_disc += [optimizer_Dr]
        
        discriminator_ff = Discriminator() #for fake data (hat_Y) in W(hat_Y, hat_Y)
        optimizer_Dff = torch.optim.RMSprop(discriminator_ff.parameters(), lr = 0.01)
        optimizers_disc += [optimizer_Dff]

# %%
optimizer_G = torch.optim.Adam(generator.parameters(), lr = 0.003)
optimizer_Df = torch.optim.RMSprop(discriminator_fake.parameters(),lr=0.005)
optimizer_Dr = torch.optim.RMSprop(discriminator_real.parameters(),lr=0.005)
optimizer_Dff = torch.optim.RMSprop(discriminator_ff.parameters(), lr = 0.01)

# %%
from geomloss.utils import squared_distances

# %%
eps = LAMBDA#CHANGE TO APPLY TO SINKHORN!!!
def entropic_loss_dual(dual_fake, dual_real, cost_mat):#this is a negative loss
    log_pi = (dual_real.T+dual_fake - cost_mat)/eps
    reg_term = (log_pi).logsumexp((0,1))
    W_neg = - dual_fake.mean() - dual_real.mean() + eps*reg_term 
    return W_neg

#WE CAN MINIMIZE THE LOG OF W HERE IF THERE ARE NANS
def entropic_loss_primal(dual_fake, dual_real, cost_mat):#this is a positive loss
    log_pi = ((dual_real.T+dual_fake - cost_mat)/eps).detach()
    log_exp_norm = (log_pi + torch.log(cost_mat)).logsumexp((0,1))#log of expected norm
    W = torch.exp(log_exp_norm)
    return W

def sinkhorn_loss_primal(dual_fake, dual_real, dual_ff, fake_sample, real_sample, cost_mat, cost_mat_ff):
    log_pi = ((dual_real.T+dual_fake - cost_mat)/eps - 2* np.log(dual_fake.shape[0])).detach()
    max_log_pi = torch.max(log_pi)
    pi = torch.exp(log_pi - max_log_pi)
    pi = pi / pi.sum()
    log_pi_ff = ((dual_ff.T+dual_ff - cost_mat_ff)/eps - 2* np.log(dual_fake.shape[0])).detach()
    max_log_pi_ff = torch.max(log_pi_ff)
    pi_ff = torch.exp(log_pi_ff - max_log_pi_ff)
    pi_ff = pi_ff / pi_ff.sum()
    
    scalar1 = torch.matmul(fake_sample, real_sample.T)
    expect_scalar1 = (scalar1*pi).sum()

    scalar2 = torch.matmul(fake_sample, fake_sample.T)
    expect_scalar2 = (scalar2*pi_ff).sum()

    S = -2.0*expect_scalar1 + expect_scalar2
    return S

def sinkhorn_loss_dual(dual_fake, dual_real, dual_ff, cost_mat, cost_mat_ff):#this is a negative loss 
                                                                             #(for optimization)
    S = entropic_loss_dual(dual_fake, dual_real, cost_mat)\
            - 0.5 * entropic_loss_dual(dual_ff, dual_ff, cost_mat_ff)
    return S

# %%
res = {'loss':{}, 'sample': {}, 'cov_diff' : {}, 'cov_diff_accurate' : {}}
if MODE in ['divergence', 'loss']:
    res['lambda'] = LAMBDA
cov_diff_all = []
epochs = EPOCHS
VAL_STEP = 10 #compute validation every VAL_STEP iterations

# %%
acc_cov_diff = []

cov_diff_inp = torch.tensor(np.random.randn(10*BATCH_SIZE, LATENT_DIM).astype('float32'))

# %%
CRITIC_ITERS = 20

# %%
epochs_passed = len(list(res['loss'].keys()))#to continue training 
loss_primal = 0
for epoch in range(epochs_passed, epochs_passed+epochs):
#     if MODE == 'divergence' and PARAMETRIC:
#         if epoch == 15:
#                 optimizer_G.param_groups[0]['lr'] = 0.001
#         if epoch == 25:
#                 optimizer_G.param_groups[0]['lr'] = 0.0007
#         if epoch == 35:
#                 optimizer_G.param_groups[0]['lr'] = 0.0005
#                 optimizer_Df.param_groups[0]['lr'] = 0.0025
#                 optimizer_Dr.param_groups[0]['lr'] = 0.0025
#                 optimizer_Dff.param_groups[0]['lr'] = 0.005
    for key in res:
        if key != 'lambda':
            res[key][epoch] = []
    # go through all the batches generated by dataloader
    for i, (inputs, real_sample, inputs0, inputs1) in enumerate(data_dl):
        # clear the gradients
        for optimizer in optimizers_disc:
            optimizer.zero_grad()

        # compute the discriminator model outputs & update
        fake_sample = generator(inputs)

        cov_diff = np.linalg.norm(np.cov(np.array(fake_sample.data).T) - np.eye(DATA_DIM)/COVARIANCE_SCALE)
        cost_mat = squared_distances(fake_sample, real_sample)
        cost_mat_ff = squared_distances(fake_sample, fake_sample)
        dual_fake = discriminator_fake(fake_sample)
        dual_ff = discriminator_ff(fake_sample)
        dual_real = discriminator_real(real_sample)
        loss_w2 = entropic_loss_dual(dual_fake, dual_real, cost_mat)
        loss_w2.backward(retain_graph=True)
        optimizer_Dr.step()
        optimizer_Df.step()

        loss_neg_ent = entropic_loss_dual(dual_ff, dual_ff, cost_mat_ff)
        loss_neg_ent.backward()
        optimizer_Dff.step()

        #Sinkhorn negentropy update
        #fake_sample0 = fake_sample#generator(inputs0)
        #fake_sample1 = fake_sample#generator(inputs1)
        #cost_mat_ff = squared_distances(fake_sample0, fake_sample1)
        #dual_ff0 = discriminator_ff(fake_sample0)
        #dual_ff1 = discriminator_ff(fake_sample1)
        #loss_dual_f = sinkhorn_loss_dual(dual_ff0, dual_ff1, cost_mat_ff)
        #loss_dual_f.backward()
        #optimizer_Dff.step()
        loss_dual = loss_w2 - 0.5*loss_neg_ent
        
        if i % CRITIC_ITERS == 0 and i>0:
            # -----------------
            #  Train Generator
            # -----------------
            print("Generator step")
            optimizer_G.zero_grad()
            
            fake_sample = generator(inputs)
            cost_mat = squared_distances(fake_sample, real_sample)
            dual_fake = discriminator_fake(fake_sample)
            dual_real = discriminator_real(real_sample)
            cost_mat_ff = squared_distances(fake_sample, fake_sample)
            loss_primal = sinkhorn_loss_primal(dual_fake, dual_real, dual_ff, fake_sample,
                                             real_sample, cost_mat, cost_mat_ff)
            #fake_sample0 = generator(inputs0)
            #fake_sample1 = generator(inputs1)
            #cost_mat_ff = squared_distances(fake_sample0, fake_sample1)
            #dual_ff0 = discriminator_ff(fake_sample0)
            #dual_ff1 = discriminator_ff(fake_sample1)
            #loss_dual_f = sinkhorn_loss_dual(dual_ff0, dual_ff1, cost_mat_ff)
            
            #loss_G = - loss_dual + 0.5*loss_dual_f
            loss_primal.backward()
            optimizer_G.step()
        if i % 50 == 0:
            fake_sample = generator(cov_diff_inp)
            acc_cov_diff += [np.linalg.norm(np.cov(np.array(fake_sample.data).T) - 
                                      np.eye(DATA_DIM)/COVARIANCE_SCALE)]
        loss_dual = loss_w2-0.5*loss_neg_ent
        print("Epoch: {}, iteration {}, loss {:.4f}, loss_p {:.4f}, cov_diff {}".format(epoch,
                                                                                i, loss_dual, 
                                                                                loss_primal, cov_diff))
        res['loss'][epoch].append([loss_dual, loss_primal])
        res['sample'][epoch].append(np.array(fake_sample.data))
        res['cov_diff'][epoch].append(cov_diff)
    cov_diff_all += res['cov_diff'][epoch]
# Out:
# Epoch: 30, iteration 0, loss -2.2465, loss_p 0.0000, cov_diff 0.7553152107878301
# Epoch: 30, iteration 1, loss -1.6496, loss_p 0.0000, cov_diff 0.7625515334414817
# Epoch: 30, iteration 2, loss -1.6439, loss_p 0.0000, cov_diff 0.7611266596795976
# Epoch: 30, iteration 3, loss -1.9963, loss_p 0.0000, cov_diff 0.7587621546514176
# Epoch: 30, iteration 4, loss -2.0644, loss_p 0.0000, cov_diff 0.7571143114272132
# Epoch: 30, iteration 5, loss -2.0958, loss_p 0.0000, cov_diff 0.7647413309683366
# Epoch: 30, iteration 6, loss -2.0359, loss_p 0.0000, cov_diff 0.7707289958415676
# Epoch: 30, iteration 7, loss -2.1315, loss_p 0.0000, cov_diff 0.7686986413449248
# Epoch: 30, iteration 8, loss -2.2031, loss_p 0.0000, cov_diff 0.7641130575420362
# Epoch: 30, iteration 9, loss -2.2204, loss_p 0.0000, cov_diff 0.7649372724702823
# Epoch: 30, iteration 10, loss -2.0856, loss_p 0.0000, cov_diff 0.767581570752822
# Epoch: 30, iteration 11, loss -2.1640, loss_p 0.0000, cov_diff 0.7649209211683987
# Epoch: 30, iteration 12, loss -2.1802, loss_p 0.0000, cov_diff 0.7483431946196563
# Epoch: 30, iteration 13, loss -2.1367, loss_p 0.0000, cov_diff 0.7653199132964237
# Epoch: 30, iteration 14, loss -2.2907, loss_p 0.0000, cov_diff 0.7642273894745794
# Epoch: 30, iteration 15, loss -2.1476, loss_p 0.0000, cov_diff 0.7548336578845434
# Epoch: 30, iteration 16, loss -2.1182, loss_p 0.0000, cov_diff 0.7729998986103181
# Epoch: 30, iteration 17, loss -1.9681, loss_p 0.0000, cov_diff 0.7672720719952697
# Epoch: 30, iteration 18, loss -2.1771, loss_p 0.0000, cov_diff 0.7763543742694355
# Epoch: 30, iteration 19, loss -2.2987, loss_p 0.0000, cov_diff 0.7595806844854067
# Generator step
# Epoch: 30, iteration 20, loss -2.0664, loss_p -0.6802, cov_diff 0.7704148623129163
# Epoch: 30, iteration 21, loss -2.1551, loss_p -0.6802, cov_diff 0.7539532948908753
# Epoch: 30, iteration 22, loss -2.2581, loss_p -0.6802, cov_diff 0.7518818392713571
# Epoch: 30, iteration 23, loss -2.3802, loss_p -0.6802, cov_diff 0.7498152356511674
# Epoch: 30, iteration 24, loss -2.3655, loss_p -0.6802, cov_diff 0.7445753797669328
# Epoch: 30, iteration 25, loss -2.4394, loss_p -0.6802, cov_diff 0.7376388249990431
# Epoch: 30, iteration 26, loss -2.3156, loss_p -0.6802, cov_diff 0.7478702102397718
# Epoch: 30, iteration 27, loss -2.2471, loss_p -0.6802, cov_diff 0.7438035885131997
# Epoch: 30, iteration 28, loss -2.2557, loss_p -0.6802, cov_diff 0.7441801847969228
# Epoch: 30, iteration 29, loss -2.4092, loss_p -0.6802, cov_diff 0.7434567307925969
# Epoch: 30, iteration 30, loss -2.1459, loss_p -0.6802, cov_diff 0.7448253027041389
# Epoch: 30, iteration 31, loss -2.4015, loss_p -0.6802, cov_diff 0.7465635342412836
# Epoch: 30, iteration 32, loss -2.2976, loss_p -0.6802, cov_diff 0.7527140872926946
# Epoch: 30, iteration 33, loss -2.3034, loss_p -0.6802, cov_diff 0.7579924672431235
# Epoch: 30, iteration 34, loss -2.4516, loss_p -0.6802, cov_diff 0.7543604145364015
# Epoch: 30, iteration 35, loss -2.3510, loss_p -0.6802, cov_diff 0.7509097015310365
# Epoch: 30, iteration 36, loss -2.2585, loss_p -0.6802, cov_diff 0.7438531368144136
# Epoch: 30, iteration 37, loss -2.3328, loss_p -0.6802, cov_diff 0.7466388875100178
# Epoch: 30, iteration 38, loss -2.4022, loss_p -0.6802, cov_diff 0.7572094464775261
# Epoch: 30, iteration 39, loss -2.2866, loss_p -0.6802, cov_diff 0.7610769041417333
# Generator step
# Epoch: 30, iteration 40, loss -2.4608, loss_p -0.7062, cov_diff 0.7474864812506632
# Epoch: 30, iteration 41, loss -2.3935, loss_p -0.7062, cov_diff 0.7614687238147244
# Epoch: 30, iteration 42, loss -2.2980, loss_p -0.7062, cov_diff 0.7603644891653888
# Epoch: 30, iteration 43, loss -2.3040, loss_p -0.7062, cov_diff 0.767612087943727
# Epoch: 30, iteration 44, loss -2.4796, loss_p -0.7062, cov_diff 0.7498904705150227
# Epoch: 30, iteration 45, loss -2.3710, loss_p -0.7062, cov_diff 0.7561142136771685
# Epoch: 30, iteration 46, loss -2.3730, loss_p -0.7062, cov_diff 0.7665198225030923
# Epoch: 30, iteration 47, loss -2.4257, loss_p -0.7062, cov_diff 0.7706364014757743
# Epoch: 30, iteration 48, loss -2.2906, loss_p -0.7062, cov_diff 0.7711323337278861
# Epoch: 30, iteration 49, loss -2.2324, loss_p -0.7062, cov_diff 0.7647884103754967
# Epoch: 30, iteration 50, loss -2.2892, loss_p -0.7062, cov_diff 0.7673516614620985
# Epoch: 30, iteration 51, loss -2.4364, loss_p -0.7062, cov_diff 0.7634901630850398
# Epoch: 30, iteration 52, loss -2.3668, loss_p -0.7062, cov_diff 0.7686813433860918
# Epoch: 30, iteration 53, loss -2.1482, loss_p -0.7062, cov_diff 0.772948359194915
# Epoch: 30, iteration 54, loss -2.4079, loss_p -0.7062, cov_diff 0.7723925664302311
# Epoch: 30, iteration 55, loss -2.3823, loss_p -0.7062, cov_diff 0.7669253044573964
# Epoch: 30, iteration 56, loss -2.3026, loss_p -0.7062, cov_diff 0.7712787665986177
# Epoch: 30, iteration 57, loss -2.3838, loss_p -0.7062, cov_diff 0.7586523136128638
# Epoch: 30, iteration 58, loss -2.2613, loss_p -0.7062, cov_diff 0.7765845523379293
# Epoch: 30, iteration 59, loss -2.3709, loss_p -0.7062, cov_diff 0.7671191192283637
# Generator step
# Epoch: 30, iteration 60, loss -2.3784, loss_p -0.7723, cov_diff 0.7655119178566555
# Epoch: 30, iteration 61, loss -2.3597, loss_p -0.7723, cov_diff 0.7749714505679284
# Epoch: 30, iteration 62, loss -2.2595, loss_p -0.7723, cov_diff 0.7759163014687164
# Epoch: 30, iteration 63, loss -2.3266, loss_p -0.7723, cov_diff 0.7731349742930821
# Epoch: 30, iteration 64, loss -2.2254, loss_p -0.7723, cov_diff 0.7681874216837482
# Epoch: 30, iteration 65, loss -2.1882, loss_p -0.7723, cov_diff 0.7665392732264352
# Epoch: 30, iteration 66, loss -2.1665, loss_p -0.7723, cov_diff 0.7726327756634003
# Epoch: 30, iteration 67, loss -2.2836, loss_p -0.7723, cov_diff 0.7770767894287023
# Epoch: 30, iteration 68, loss -2.2779, loss_p -0.7723, cov_diff 0.781041593730943
# Epoch: 30, iteration 69, loss -2.3912, loss_p -0.7723, cov_diff 0.773948599843929
# Epoch: 30, iteration 70, loss -2.2478, loss_p -0.7723, cov_diff 0.7722617764870027
# Epoch: 30, iteration 71, loss -2.3696, loss_p -0.7723, cov_diff 0.773692600779637
# Epoch: 30, iteration 72, loss -2.1503, loss_p -0.7723, cov_diff 0.7838977693524743
# Epoch: 30, iteration 73, loss -2.2705, loss_p -0.7723, cov_diff 0.7816570896422886
# Epoch: 30, iteration 74, loss -2.3753, loss_p -0.7723, cov_diff 0.781347737986744
# Epoch: 30, iteration 75, loss -2.3892, loss_p -0.7723, cov_diff 0.7767034697388108
# Epoch: 30, iteration 76, loss -2.2335, loss_p -0.7723, cov_diff 0.7714229134233258
# Epoch: 30, iteration 77, loss -2.3286, loss_p -0.7723, cov_diff 0.7838716336165216
# Epoch: 30, iteration 78, loss -2.2546, loss_p -0.7723, cov_diff 0.7745274261395401
# Epoch: 30, iteration 79, loss -2.3589, loss_p -0.7723, cov_diff 0.7744830965616145
# Generator step
# Epoch: 30, iteration 80, loss -2.3458, loss_p -0.7289, cov_diff 0.7779112265198805
# Epoch: 30, iteration 81, loss -2.2670, loss_p -0.7289, cov_diff 0.7843884928553562
# Epoch: 30, iteration 82, loss -2.3009, loss_p -0.7289, cov_diff 0.7731419384876348
# Epoch: 30, iteration 83, loss -2.3113, loss_p -0.7289, cov_diff 0.7727998556866364
# Epoch: 30, iteration 84, loss -2.2939, loss_p -0.7289, cov_diff 0.7844406109472993
# Epoch: 30, iteration 85, loss -2.3231, loss_p -0.7289, cov_diff 0.7860292711408746
# Epoch: 30, iteration 86, loss -2.2869, loss_p -0.7289, cov_diff 0.7860045771265077
# Epoch: 30, iteration 87, loss -2.3463, loss_p -0.7289, cov_diff 0.7927626550385092
# Epoch: 30, iteration 88, loss -2.4587, loss_p -0.7289, cov_diff 0.7739955129539825
# Epoch: 30, iteration 89, loss -2.2320, loss_p -0.7289, cov_diff 0.7833470972016514
# Epoch: 30, iteration 90, loss -2.1827, loss_p -0.7289, cov_diff 0.7822953529797473
# Epoch: 30, iteration 91, loss -2.4108, loss_p -0.7289, cov_diff 0.7793389637735377
# Epoch: 30, iteration 92, loss -2.3753, loss_p -0.7289, cov_diff 0.7762394188216303
# Epoch: 30, iteration 93, loss -2.3731, loss_p -0.7289, cov_diff 0.7825481739117267
# Epoch: 30, iteration 94, loss -2.3209, loss_p -0.7289, cov_diff 0.7846308290501157
# Epoch: 30, iteration 95, loss -2.2670, loss_p -0.7289, cov_diff 0.7905831445806131
# Epoch: 30, iteration 96, loss -2.4249, loss_p -0.7289, cov_diff 0.7786370931855182
# Epoch: 30, iteration 97, loss -2.2601, loss_p -0.7289, cov_diff 0.779649100166577
# Epoch: 30, iteration 98, loss -2.3075, loss_p -0.7289, cov_diff 0.7786398516810146
# Epoch: 30, iteration 99, loss -2.3837, loss_p -0.7289, cov_diff 0.7895284511922998
# Generator step
# Epoch: 30, iteration 100, loss -2.2136, loss_p -0.6749, cov_diff 0.7876325551751081
# Epoch: 30, iteration 101, loss -2.1729, loss_p -0.6749, cov_diff 0.7794585549207718
# Epoch: 30, iteration 102, loss -2.3414, loss_p -0.6749, cov_diff 0.7808608445846523
# Epoch: 30, iteration 103, loss -2.3058, loss_p -0.6749, cov_diff 0.783463542666187
# Epoch: 30, iteration 104, loss -2.3606, loss_p -0.6749, cov_diff 0.7785015753979238
# Epoch: 30, iteration 105, loss -2.4484, loss_p -0.6749, cov_diff 0.7648395772541288
# Epoch: 30, iteration 106, loss -2.2677, loss_p -0.6749, cov_diff 0.7768241959671739
# Epoch: 30, iteration 107, loss -2.4287, loss_p -0.6749, cov_diff 0.7736120322643377
# Epoch: 30, iteration 108, loss -2.2898, loss_p -0.6749, cov_diff 0.7851354222625514
# Epoch: 30, iteration 109, loss -2.3231, loss_p -0.6749, cov_diff 0.7884612263680612
# Epoch: 30, iteration 110, loss -2.3458, loss_p -0.6749, cov_diff 0.7787233730117783
# Epoch: 30, iteration 111, loss -2.3366, loss_p -0.6749, cov_diff 0.780591005940627
# Epoch: 30, iteration 112, loss -2.3653, loss_p -0.6749, cov_diff 0.7650945104537102
# Epoch: 30, iteration 113, loss -2.1921, loss_p -0.6749, cov_diff 0.7844219116661727
# Epoch: 30, iteration 114, loss -2.3740, loss_p -0.6749, cov_diff 0.7754130148483475
# Epoch: 30, iteration 115, loss -2.4546, loss_p -0.6749, cov_diff 0.776599574138282
# Epoch: 30, iteration 116, loss -2.2381, loss_p -0.6749, cov_diff 0.7781175237955191
# Epoch: 30, iteration 117, loss -2.3152, loss_p -0.6749, cov_diff 0.7764485538789365
# Epoch: 30, iteration 118, loss -2.3461, loss_p -0.6749, cov_diff 0.7731796596671432
# Epoch: 30, iteration 119, loss -2.2661, loss_p -0.6749, cov_diff 0.7817199115390899
# Generator step
# Epoch: 30, iteration 120, loss -2.4130, loss_p -0.8046, cov_diff 0.7843851287831747
# Epoch: 30, iteration 121, loss -2.4387, loss_p -0.8046, cov_diff 0.7808960536298749
# Epoch: 30, iteration 122, loss -2.4185, loss_p -0.8046, cov_diff 0.7686949128759807
# Epoch: 30, iteration 123, loss -2.4393, loss_p -0.8046, cov_diff 0.7746106885536159
# Epoch: 30, iteration 124, loss -2.4162, loss_p -0.8046, cov_diff 0.7728398735504443
# Epoch: 30, iteration 125, loss -2.4612, loss_p -0.8046, cov_diff 0.787528608346848
# Epoch: 30, iteration 126, loss -2.4094, loss_p -0.8046, cov_diff 0.7757353245389572
# Epoch: 30, iteration 127, loss -2.3624, loss_p -0.8046, cov_diff 0.7773381752036861
# Epoch: 30, iteration 128, loss -2.3083, loss_p -0.8046, cov_diff 0.7714269050070681
# Epoch: 30, iteration 129, loss -2.3528, loss_p -0.8046, cov_diff 0.7820155831921047
# Epoch: 30, iteration 130, loss -2.2425, loss_p -0.8046, cov_diff 0.7645891090233853
# Epoch: 30, iteration 131, loss -2.3443, loss_p -0.8046, cov_diff 0.7853522454825971
# Epoch: 30, iteration 132, loss -2.2879, loss_p -0.8046, cov_diff 0.7686968002132039
# Epoch: 30, iteration 133, loss -2.3389, loss_p -0.8046, cov_diff 0.7706407899415688
# Epoch: 30, iteration 134, loss -2.3984, loss_p -0.8046, cov_diff 0.7789365651413204
# Epoch: 30, iteration 135, loss -2.3201, loss_p -0.8046, cov_diff 0.7750972081989805
# Epoch: 30, iteration 136, loss -2.2581, loss_p -0.8046, cov_diff 0.7755525196989328
# Epoch: 30, iteration 137, loss -2.3022, loss_p -0.8046, cov_diff 0.7870799985452289
# Epoch: 30, iteration 138, loss -2.3525, loss_p -0.8046, cov_diff 0.7723459969276802
# Epoch: 30, iteration 139, loss -2.3919, loss_p -0.8046, cov_diff 0.7701882870204404
# Generator step
# Epoch: 30, iteration 140, loss -2.4156, loss_p -0.7642, cov_diff 0.7832868383007232
# Epoch: 30, iteration 141, loss -2.3175, loss_p -0.7642, cov_diff 0.766274481886144
# Epoch: 30, iteration 142, loss -2.3394, loss_p -0.7642, cov_diff 0.7691506027347489
# Epoch: 30, iteration 143, loss -2.1839, loss_p -0.7642, cov_diff 0.7733876426668009
# Epoch: 30, iteration 144, loss -2.1749, loss_p -0.7642, cov_diff 0.7631690795376237
# Epoch: 30, iteration 145, loss -2.2093, loss_p -0.7642, cov_diff 0.7712740067283438
# Epoch: 30, iteration 146, loss -2.3089, loss_p -0.7642, cov_diff 0.778350864385717
# Epoch: 30, iteration 147, loss -2.3159, loss_p -0.7642, cov_diff 0.7768681018125038
# Epoch: 30, iteration 148, loss -2.2409, loss_p -0.7642, cov_diff 0.7702173204318571
# Epoch: 30, iteration 149, loss -2.4100, loss_p -0.7642, cov_diff 0.770857569009394
# Epoch: 30, iteration 150, loss -2.3657, loss_p -0.7642, cov_diff 0.7733883673497488
# Epoch: 30, iteration 151, loss -2.3980, loss_p -0.7642, cov_diff 0.7814633251517449
# Epoch: 30, iteration 152, loss -2.2739, loss_p -0.7642, cov_diff 0.7759873586046003
# Epoch: 30, iteration 153, loss -2.2321, loss_p -0.7642, cov_diff 0.7722588022833087
# Epoch: 30, iteration 154, loss -2.3900, loss_p -0.7642, cov_diff 0.7768709467367868
# Epoch: 30, iteration 155, loss -2.3255, loss_p -0.7642, cov_diff 0.769329465436502
# Epoch: 30, iteration 156, loss -2.3167, loss_p -0.7642, cov_diff 0.7626719787678643
# Epoch: 30, iteration 157, loss -2.0815, loss_p -0.7642, cov_diff 0.7913393569842505
# Epoch: 30, iteration 158, loss -2.2240, loss_p -0.7642, cov_diff 0.77618617644781
# Epoch: 30, iteration 159, loss -2.1765, loss_p -0.7642, cov_diff 0.7767057379989935
# Generator step
# Epoch: 30, iteration 160, loss -2.3568, loss_p -0.8113, cov_diff 0.774538132677033
# Epoch: 30, iteration 161, loss -2.2689, loss_p -0.8113, cov_diff 0.7716640796266315
# Epoch: 30, iteration 162, loss -2.2125, loss_p -0.8113, cov_diff 0.7676477365225531
# Epoch: 30, iteration 163, loss -2.3602, loss_p -0.8113, cov_diff 0.7716178219204786
# Epoch: 30, iteration 164, loss -2.2364, loss_p -0.8113, cov_diff 0.7620587884466004
# Epoch: 30, iteration 165, loss -2.2117, loss_p -0.8113, cov_diff 0.7632779668865382
# Epoch: 30, iteration 166, loss -2.3329, loss_p -0.8113, cov_diff 0.7691011617484635
# Epoch: 30, iteration 167, loss -2.2270, loss_p -0.8113, cov_diff 0.7744774886342287
# Epoch: 30, iteration 168, loss -2.2271, loss_p -0.8113, cov_diff 0.7664984909570984
# Epoch: 30, iteration 169, loss -2.3330, loss_p -0.8113, cov_diff 0.7685483447947578
# Epoch: 30, iteration 170, loss -2.1857, loss_p -0.8113, cov_diff 0.7652073835898409
# Epoch: 30, iteration 171, loss -2.2285, loss_p -0.8113, cov_diff 0.7708083429234686
# Epoch: 30, iteration 172, loss -2.2570, loss_p -0.8113, cov_diff 0.7696374799900795
# Epoch: 30, iteration 173, loss -2.3475, loss_p -0.8113, cov_diff 0.770171740158623
# Epoch: 30, iteration 174, loss -2.3075, loss_p -0.8113, cov_diff 0.7605945056295416
# Epoch: 30, iteration 175, loss -2.2659, loss_p -0.8113, cov_diff 0.7644086714187809
# Epoch: 30, iteration 176, loss -2.3687, loss_p -0.8113, cov_diff 0.759617216666773
# Epoch: 30, iteration 177, loss -2.3431, loss_p -0.8113, cov_diff 0.77111424755128
# Epoch: 30, iteration 178, loss -2.3747, loss_p -0.8113, cov_diff 0.7710034797619755
# Epoch: 30, iteration 179, loss -2.3638, loss_p -0.8113, cov_diff 0.766869373322596
# Generator step
# Epoch: 30, iteration 180, loss -2.2849, loss_p -0.7995, cov_diff 0.7662133483118915
# Epoch: 30, iteration 181, loss -2.4220, loss_p -0.7995, cov_diff 0.771028606991208
# Epoch: 30, iteration 182, loss -2.3210, loss_p -0.7995, cov_diff 0.7653592135448389
# Epoch: 30, iteration 183, loss -2.3714, loss_p -0.7995, cov_diff 0.7594580316588441
# Epoch: 30, iteration 184, loss -2.4115, loss_p -0.7995, cov_diff 0.7558167103305703
# Epoch: 30, iteration 185, loss -2.3662, loss_p -0.7995, cov_diff 0.7693554643968451
# Epoch: 30, iteration 186, loss -2.2331, loss_p -0.7995, cov_diff 0.7675090277465986
# Epoch: 30, iteration 187, loss -2.4019, loss_p -0.7995, cov_diff 0.7643393065450684
# Epoch: 30, iteration 188, loss -2.2543, loss_p -0.7995, cov_diff 0.7634237223764995
# Epoch: 30, iteration 189, loss -2.2530, loss_p -0.7995, cov_diff 0.7662781651058692
# Epoch: 30, iteration 190, loss -2.3697, loss_p -0.7995, cov_diff 0.762436096698567
# Epoch: 30, iteration 191, loss -2.2135, loss_p -0.7995, cov_diff 0.7684467649189116
# Epoch: 30, iteration 192, loss -2.3651, loss_p -0.7995, cov_diff 0.765454224888438
# Epoch: 30, iteration 193, loss -2.2430, loss_p -0.7995, cov_diff 0.7606695602721378
# Epoch: 30, iteration 194, loss -2.3716, loss_p -0.7995, cov_diff 0.7690397471086419
# Epoch: 30, iteration 195, loss -2.3836, loss_p -0.7995, cov_diff 0.7557945690636678
# Epoch: 30, iteration 196, loss -2.2566, loss_p -0.7995, cov_diff 0.7712311128753083
# Epoch: 30, iteration 197, loss -2.1191, loss_p -0.7995, cov_diff 0.7678204687362992
# Epoch: 30, iteration 198, loss -2.2484, loss_p -0.7995, cov_diff 0.7607847278706078
# Epoch: 30, iteration 199, loss -2.3208, loss_p -0.7995, cov_diff 0.760689240086615
# Generator step
# Epoch: 30, iteration 200, loss -2.2074, loss_p -0.6712, cov_diff 0.7638981245551761
# Epoch: 30, iteration 201, loss -2.2923, loss_p -0.6712, cov_diff 0.7673872087976311
# Epoch: 30, iteration 202, loss -2.3831, loss_p -0.6712, cov_diff 0.7679393821230822
# Epoch: 30, iteration 203, loss -2.2989, loss_p -0.6712, cov_diff 0.7697017217395032
# Epoch: 30, iteration 204, loss -2.3634, loss_p -0.6712, cov_diff 0.7650306974059184
# Epoch: 30, iteration 205, loss -2.1802, loss_p -0.6712, cov_diff 0.7756967303541245
# Epoch: 30, iteration 206, loss -2.3757, loss_p -0.6712, cov_diff 0.7689086682417765
# Epoch: 30, iteration 207, loss -2.2377, loss_p -0.6712, cov_diff 0.7688090690200416
# Epoch: 30, iteration 208, loss -2.1561, loss_p -0.6712, cov_diff 0.7753457482027802
# Epoch: 30, iteration 209, loss -2.2208, loss_p -0.6712, cov_diff 0.7660729522350602
# Epoch: 30, iteration 210, loss -2.2344, loss_p -0.6712, cov_diff 0.7641361968330064
# Epoch: 30, iteration 211, loss -2.2600, loss_p -0.6712, cov_diff 0.7612014530516403
# Epoch: 30, iteration 212, loss -2.2448, loss_p -0.6712, cov_diff 0.777226637689819
# Epoch: 30, iteration 213, loss -2.1381, loss_p -0.6712, cov_diff 0.761523103207721
# Epoch: 30, iteration 214, loss -2.3066, loss_p -0.6712, cov_diff 0.7690020616955635
# Epoch: 30, iteration 215, loss -2.3567, loss_p -0.6712, cov_diff 0.7659419733241284
# Epoch: 30, iteration 216, loss -2.3783, loss_p -0.6712, cov_diff 0.772381649789423
# Epoch: 30, iteration 217, loss -2.2823, loss_p -0.6712, cov_diff 0.7638666919711762
# Epoch: 30, iteration 218, loss -2.2646, loss_p -0.6712, cov_diff 0.7728615684637692
# Epoch: 30, iteration 219, loss -2.3540, loss_p -0.6712, cov_diff 0.7674011928653487
# Generator step
# Epoch: 30, iteration 220, loss -2.1811, loss_p -0.7761, cov_diff 0.7642964254596937
# Epoch: 30, iteration 221, loss -2.2282, loss_p -0.7761, cov_diff 0.7750648361679418
# Epoch: 30, iteration 222, loss -2.2852, loss_p -0.7761, cov_diff 0.775961446376392
# Epoch: 30, iteration 223, loss -2.2658, loss_p -0.7761, cov_diff 0.7819711333082024
# Epoch: 30, iteration 224, loss -2.3632, loss_p -0.7761, cov_diff 0.7787731809408638
# Epoch: 30, iteration 225, loss -2.1328, loss_p -0.7761, cov_diff 0.7867770962844473
# Epoch: 30, iteration 226, loss -2.2136, loss_p -0.7761, cov_diff 0.7713357437549377
# Epoch: 30, iteration 227, loss -2.3214, loss_p -0.7761, cov_diff 0.7740126939827078
# Epoch: 30, iteration 228, loss -2.2010, loss_p -0.7761, cov_diff 0.7698961127373137
# Epoch: 30, iteration 229, loss -2.1987, loss_p -0.7761, cov_diff 0.7692603269569033
# Epoch: 30, iteration 230, loss -2.3201, loss_p -0.7761, cov_diff 0.7670749703145159
# Epoch: 30, iteration 231, loss -2.1860, loss_p -0.7761, cov_diff 0.7710132961829979
# Epoch: 30, iteration 232, loss -2.3089, loss_p -0.7761, cov_diff 0.7716603128118217
# Epoch: 30, iteration 233, loss -2.2241, loss_p -0.7761, cov_diff 0.7748065840627799
# Epoch: 30, iteration 234, loss -2.2284, loss_p -0.7761, cov_diff 0.7689161217548807
# Epoch: 30, iteration 235, loss -2.3783, loss_p -0.7761, cov_diff 0.7742878133881492
# Epoch: 30, iteration 236, loss -2.2001, loss_p -0.7761, cov_diff 0.7780260551923016
# Epoch: 30, iteration 237, loss -2.3723, loss_p -0.7761, cov_diff 0.7740853194566343
# Epoch: 30, iteration 238, loss -2.1281, loss_p -0.7761, cov_diff 0.7747231367379422
# Epoch: 30, iteration 239, loss -2.1732, loss_p -0.7761, cov_diff 0.7748908205820378
# Generator step
# Epoch: 30, iteration 240, loss -2.2497, loss_p -0.8241, cov_diff 0.778093600196155
# Epoch: 30, iteration 241, loss -2.1891, loss_p -0.8241, cov_diff 0.7763123767363882
# Epoch: 30, iteration 242, loss -2.3409, loss_p -0.8241, cov_diff 0.7654860766377624
# Epoch: 30, iteration 243, loss -2.2687, loss_p -0.8241, cov_diff 0.7716515164731692
# Epoch: 30, iteration 244, loss -2.1259, loss_p -0.8241, cov_diff 0.7820647751077527
# Epoch: 30, iteration 245, loss -2.3322, loss_p -0.8241, cov_diff 0.7820799227187525
# Epoch: 30, iteration 246, loss -2.2299, loss_p -0.8241, cov_diff 0.7758578386743122
# Epoch: 30, iteration 247, loss -2.1490, loss_p -0.8241, cov_diff 0.7695926436563185
# Epoch: 30, iteration 248, loss -2.3903, loss_p -0.8241, cov_diff 0.7781644445184284
# Epoch: 30, iteration 249, loss -2.2467, loss_p -0.8241, cov_diff 0.7746289150481966
# Epoch: 30, iteration 250, loss -2.2356, loss_p -0.8241, cov_diff 0.7732980811494293
# Epoch: 30, iteration 251, loss -2.4327, loss_p -0.8241, cov_diff 0.7754907196046548
# Epoch: 30, iteration 252, loss -2.2246, loss_p -0.8241, cov_diff 0.7692612139416474
# Epoch: 30, iteration 253, loss -2.2830, loss_p -0.8241, cov_diff 0.7770195087516324
# Epoch: 30, iteration 254, loss -2.3079, loss_p -0.8241, cov_diff 0.7846807308718388
# Epoch: 30, iteration 255, loss -2.2612, loss_p -0.8241, cov_diff 0.7769186120884697
# Epoch: 30, iteration 256, loss -2.3807, loss_p -0.8241, cov_diff 0.7761566804533852
# Epoch: 30, iteration 257, loss -2.2246, loss_p -0.8241, cov_diff 0.7806867734234706
# Epoch: 30, iteration 258, loss -2.2519, loss_p -0.8241, cov_diff 0.7765886306063065
# Epoch: 30, iteration 259, loss -2.4296, loss_p -0.8241, cov_diff 0.7657630466478498
# Generator step
# Epoch: 30, iteration 260, loss -2.1829, loss_p -0.8047, cov_diff 0.7790113908849129
# Epoch: 30, iteration 261, loss -2.3646, loss_p -0.8047, cov_diff 0.773534573733173
# Epoch: 30, iteration 262, loss -2.2752, loss_p -0.8047, cov_diff 0.785795074735756
# Epoch: 30, iteration 263, loss -2.6397, loss_p -0.8047, cov_diff 0.7697808972543644
# Epoch: 30, iteration 264, loss -2.2910, loss_p -0.8047, cov_diff 0.7776734023178726
# Epoch: 30, iteration 265, loss -2.2673, loss_p -0.8047, cov_diff 0.7764574669864158
# Epoch: 30, iteration 266, loss -2.4126, loss_p -0.8047, cov_diff 0.7870524316611169
# Epoch: 30, iteration 267, loss -2.2752, loss_p -0.8047, cov_diff 0.7820142137549391
# Epoch: 30, iteration 268, loss -2.1457, loss_p -0.8047, cov_diff 0.783697626169504
# Epoch: 30, iteration 269, loss -2.2831, loss_p -0.8047, cov_diff 0.7778507072456045
# Epoch: 30, iteration 270, loss -2.3457, loss_p -0.8047, cov_diff 0.7918389573876284
# Epoch: 30, iteration 271, loss -2.4160, loss_p -0.8047, cov_diff 0.7855269589334519
# Epoch: 30, iteration 272, loss -2.3869, loss_p -0.8047, cov_diff 0.7812372739913162
# Epoch: 30, iteration 273, loss -2.4160, loss_p -0.8047, cov_diff 0.7826971080358615
# Epoch: 30, iteration 274, loss -2.3743, loss_p -0.8047, cov_diff 0.7861394181151165
# Epoch: 30, iteration 275, loss -2.3377, loss_p -0.8047, cov_diff 0.7775230829258454
# Epoch: 30, iteration 276, loss -2.2886, loss_p -0.8047, cov_diff 0.7801510742601243
# Epoch: 30, iteration 277, loss -2.2803, loss_p -0.8047, cov_diff 0.7743346002581277
# Epoch: 30, iteration 278, loss -2.2663, loss_p -0.8047, cov_diff 0.7840329327676634
# Epoch: 30, iteration 279, loss -2.3102, loss_p -0.8047, cov_diff 0.7865402282207945
# Generator step
# Epoch: 30, iteration 280, loss -2.3135, loss_p -0.7516, cov_diff 0.7736899913078369
# Epoch: 30, iteration 281, loss -2.2329, loss_p -0.7516, cov_diff 0.7787568006276525
# Epoch: 30, iteration 282, loss -2.2671, loss_p -0.7516, cov_diff 0.7892865998823563
# Epoch: 30, iteration 283, loss -2.2687, loss_p -0.7516, cov_diff 0.7765239480151658
# Epoch: 30, iteration 284, loss -2.3643, loss_p -0.7516, cov_diff 0.7833086932759739
# Epoch: 30, iteration 285, loss -2.3609, loss_p -0.7516, cov_diff 0.7845648160707086
# Epoch: 30, iteration 286, loss -2.3680, loss_p -0.7516, cov_diff 0.788242733806764
# Epoch: 30, iteration 287, loss -2.2882, loss_p -0.7516, cov_diff 0.781960099556239
# Epoch: 30, iteration 288, loss -2.1915, loss_p -0.7516, cov_diff 0.7864712274129458
# Epoch: 30, iteration 289, loss -2.2372, loss_p -0.7516, cov_diff 0.7726068994189459
# Epoch: 30, iteration 290, loss -2.2845, loss_p -0.7516, cov_diff 0.7830584492963044
# Epoch: 30, iteration 291, loss -2.2220, loss_p -0.7516, cov_diff 0.7836693290887721
# Epoch: 30, iteration 292, loss -2.3620, loss_p -0.7516, cov_diff 0.7837266975070809
# Epoch: 30, iteration 293, loss -2.3199, loss_p -0.7516, cov_diff 0.776350016594471
# Epoch: 30, iteration 294, loss -2.2490, loss_p -0.7516, cov_diff 0.771538293598947
# Epoch: 30, iteration 295, loss -2.2184, loss_p -0.7516, cov_diff 0.783844743778359
# Epoch: 30, iteration 296, loss -2.2938, loss_p -0.7516, cov_diff 0.787641370969707
# Epoch: 30, iteration 297, loss -2.4069, loss_p -0.7516, cov_diff 0.7904041426412808
# Epoch: 30, iteration 298, loss -2.2921, loss_p -0.7516, cov_diff 0.7908140880744846
# Epoch: 30, iteration 299, loss -2.2042, loss_p -0.7516, cov_diff 0.7831774257484714
# Generator step
# Epoch: 30, iteration 300, loss -2.3033, loss_p -0.8259, cov_diff 0.7799721925715405
# Epoch: 30, iteration 301, loss -2.3382, loss_p -0.8259, cov_diff 0.7921576545455761
# Epoch: 30, iteration 302, loss -2.3076, loss_p -0.8259, cov_diff 0.7835925470825389
# Epoch: 30, iteration 303, loss -2.3299, loss_p -0.8259, cov_diff 0.7814444242868476
# Epoch: 30, iteration 304, loss -2.2790, loss_p -0.8259, cov_diff 0.7896800709646115
# Epoch: 30, iteration 305, loss -2.3586, loss_p -0.8259, cov_diff 0.7850992081939541
# Epoch: 30, iteration 306, loss -2.3503, loss_p -0.8259, cov_diff 0.7940391415078261
# Epoch: 30, iteration 307, loss -2.2560, loss_p -0.8259, cov_diff 0.7942080123761306
# Epoch: 30, iteration 308, loss -2.2934, loss_p -0.8259, cov_diff 0.7882817571569628
# Epoch: 30, iteration 309, loss -2.2917, loss_p -0.8259, cov_diff 0.7848073024084727
# Epoch: 30, iteration 310, loss -2.3669, loss_p -0.8259, cov_diff 0.7855831344944518
# Epoch: 30, iteration 311, loss -2.2358, loss_p -0.8259, cov_diff 0.7839023129410385
# Epoch: 30, iteration 312, loss -2.3399, loss_p -0.8259, cov_diff 0.7901987981666172
# Epoch: 30, iteration 313, loss -2.2407, loss_p -0.8259, cov_diff 0.7803581783414074
# Epoch: 30, iteration 314, loss -2.3214, loss_p -0.8259, cov_diff 0.7868961124459911
# Epoch: 30, iteration 315, loss -2.3106, loss_p -0.8259, cov_diff 0.779056151628567
# Epoch: 30, iteration 316, loss -2.3632, loss_p -0.8259, cov_diff 0.7925851453684206
# Epoch: 30, iteration 317, loss -2.3191, loss_p -0.8259, cov_diff 0.7805949115162121
# Epoch: 30, iteration 318, loss -2.2951, loss_p -0.8259, cov_diff 0.7827842320353896
# Epoch: 30, iteration 319, loss -2.1121, loss_p -0.8259, cov_diff 0.7774775688263963
# Generator step
# Epoch: 30, iteration 320, loss -2.3472, loss_p -0.8167, cov_diff 0.7911094285465661
# Epoch: 30, iteration 321, loss -2.2952, loss_p -0.8167, cov_diff 0.7843382762258035
# Epoch: 30, iteration 322, loss -2.3175, loss_p -0.8167, cov_diff 0.7813494146019913
# Epoch: 30, iteration 323, loss -2.2902, loss_p -0.8167, cov_diff 0.7895280204856873
# Epoch: 30, iteration 324, loss -2.3252, loss_p -0.8167, cov_diff 0.781913840557073
# Epoch: 30, iteration 325, loss -2.3387, loss_p -0.8167, cov_diff 0.7831618128449671
# Epoch: 30, iteration 326, loss -2.2589, loss_p -0.8167, cov_diff 0.7831801062260395
# Epoch: 30, iteration 327, loss -2.3076, loss_p -0.8167, cov_diff 0.7784928195299302
# Epoch: 30, iteration 328, loss -2.2494, loss_p -0.8167, cov_diff 0.7760356655441674
# Epoch: 30, iteration 329, loss -2.2862, loss_p -0.8167, cov_diff 0.7811651758117717
# Epoch: 30, iteration 330, loss -2.2290, loss_p -0.8167, cov_diff 0.7822583378538621
# Epoch: 30, iteration 331, loss -2.2334, loss_p -0.8167, cov_diff 0.7798891864287637
# Epoch: 30, iteration 332, loss -2.3405, loss_p -0.8167, cov_diff 0.7697421610831419
# Epoch: 30, iteration 333, loss -2.3374, loss_p -0.8167, cov_diff 0.7800714681018734
# Epoch: 30, iteration 334, loss -2.4124, loss_p -0.8167, cov_diff 0.7883702933269037
# Epoch: 30, iteration 335, loss -2.3247, loss_p -0.8167, cov_diff 0.7856288047932402
# Epoch: 30, iteration 336, loss -2.4848, loss_p -0.8167, cov_diff 0.7877093162188249
# Epoch: 30, iteration 337, loss -2.3811, loss_p -0.8167, cov_diff 0.7830944778341655
# Epoch: 30, iteration 338, loss -2.3196, loss_p -0.8167, cov_diff 0.7840826131431384
# Epoch: 30, iteration 339, loss -2.2862, loss_p -0.8167, cov_diff 0.7824215056084258
# Generator step
# Epoch: 30, iteration 340, loss -2.2660, loss_p -0.8206, cov_diff 0.7979442578717724
# Epoch: 30, iteration 341, loss -2.2910, loss_p -0.8206, cov_diff 0.7870511323369599
# Epoch: 30, iteration 342, loss -2.2591, loss_p -0.8206, cov_diff 0.7786104189611887
# Epoch: 30, iteration 343, loss -2.3149, loss_p -0.8206, cov_diff 0.7857494510407238
# Epoch: 30, iteration 344, loss -2.2184, loss_p -0.8206, cov_diff 0.7840964220867943
# Epoch: 30, iteration 345, loss -2.3423, loss_p -0.8206, cov_diff 0.7854724205602652
# Epoch: 30, iteration 346, loss -2.4155, loss_p -0.8206, cov_diff 0.7819850550760179
# Epoch: 30, iteration 347, loss -2.4411, loss_p -0.8206, cov_diff 0.7745327511885015
# Epoch: 30, iteration 348, loss -2.2477, loss_p -0.8206, cov_diff 0.7905985802746873
# Epoch: 30, iteration 349, loss -2.3612, loss_p -0.8206, cov_diff 0.7821111202424222
# Epoch: 30, iteration 350, loss -2.2739, loss_p -0.8206, cov_diff 0.7869922497847156
# Epoch: 30, iteration 351, loss -2.1955, loss_p -0.8206, cov_diff 0.7829836955017173
# Epoch: 30, iteration 352, loss -2.3851, loss_p -0.8206, cov_diff 0.7801986584559384
# Epoch: 30, iteration 353, loss -2.3493, loss_p -0.8206, cov_diff 0.7881441158846456
# Epoch: 30, iteration 354, loss -2.3039, loss_p -0.8206, cov_diff 0.7898192460581497
# Epoch: 30, iteration 355, loss -2.3656, loss_p -0.8206, cov_diff 0.7895786587864371
# Epoch: 30, iteration 356, loss -2.2533, loss_p -0.8206, cov_diff 0.7810443591827939
# Epoch: 30, iteration 357, loss -2.3297, loss_p -0.8206, cov_diff 0.7756469665864737
# Epoch: 30, iteration 358, loss -2.2608, loss_p -0.8206, cov_diff 0.7862609192594604
# Epoch: 30, iteration 359, loss -2.3384, loss_p -0.8206, cov_diff 0.7970932503771652
# Generator step
# Epoch: 30, iteration 360, loss -2.2767, loss_p -0.7411, cov_diff 0.7844773257506981
# Epoch: 30, iteration 361, loss -2.2591, loss_p -0.7411, cov_diff 0.7781647376083416
# Epoch: 30, iteration 362, loss -2.2069, loss_p -0.7411, cov_diff 0.7778228514987877
# Epoch: 30, iteration 363, loss -2.4022, loss_p -0.7411, cov_diff 0.7734571990589795
# Epoch: 30, iteration 364, loss -2.3029, loss_p -0.7411, cov_diff 0.7891187494718828
# Epoch: 30, iteration 365, loss -2.1719, loss_p -0.7411, cov_diff 0.7764397535003472
# Epoch: 30, iteration 366, loss -2.3568, loss_p -0.7411, cov_diff 0.7884069526944005
# Epoch: 30, iteration 367, loss -2.3034, loss_p -0.7411, cov_diff 0.7783795005516673
# Epoch: 30, iteration 368, loss -2.2362, loss_p -0.7411, cov_diff 0.7839995143034503
# Epoch: 30, iteration 369, loss -2.3055, loss_p -0.7411, cov_diff 0.7886949154593641
# Epoch: 30, iteration 370, loss -2.1970, loss_p -0.7411, cov_diff 0.7767844236779964
# Epoch: 30, iteration 371, loss -2.3155, loss_p -0.7411, cov_diff 0.7913469659607212
# Epoch: 30, iteration 372, loss -2.3399, loss_p -0.7411, cov_diff 0.786970781718322
# Epoch: 30, iteration 373, loss -2.2009, loss_p -0.7411, cov_diff 0.7816915647062679
# Epoch: 30, iteration 374, loss -2.2239, loss_p -0.7411, cov_diff 0.7857328939179612
# Epoch: 30, iteration 375, loss -2.1392, loss_p -0.7411, cov_diff 0.7833669786554674
# Epoch: 30, iteration 376, loss -2.2513, loss_p -0.7411, cov_diff 0.7879289567089071
# Epoch: 30, iteration 377, loss -2.2274, loss_p -0.7411, cov_diff 0.775910460659446
# Epoch: 30, iteration 378, loss -2.2628, loss_p -0.7411, cov_diff 0.7869949075081746
# Epoch: 30, iteration 379, loss -2.3030, loss_p -0.7411, cov_diff 0.7852572569663557
# Generator step
# Epoch: 30, iteration 380, loss -2.1225, loss_p -0.8508, cov_diff 0.7785092046593849
# Epoch: 30, iteration 381, loss -2.1973, loss_p -0.8508, cov_diff 0.7767920861626463
# Epoch: 30, iteration 382, loss -2.3468, loss_p -0.8508, cov_diff 0.7878655291101495
# Epoch: 30, iteration 383, loss -2.2018, loss_p -0.8508, cov_diff 0.7845957167397607
# Epoch: 30, iteration 384, loss -2.1324, loss_p -0.8508, cov_diff 0.7832276211616592
# Epoch: 30, iteration 385, loss -2.3762, loss_p -0.8508, cov_diff 0.772409326101645
# Epoch: 30, iteration 386, loss -2.3174, loss_p -0.8508, cov_diff 0.7835824615786292
# Epoch: 30, iteration 387, loss -2.3179, loss_p -0.8508, cov_diff 0.7798889146509844
# Epoch: 30, iteration 388, loss -2.2673, loss_p -0.8508, cov_diff 0.788132305248518
# Epoch: 30, iteration 389, loss -2.3019, loss_p -0.8508, cov_diff 0.7843690405502505
# Epoch: 30, iteration 390, loss -2.5928, loss_p -0.8508, cov_diff 0.789561204380024
# Epoch: 31, iteration 0, loss -2.2217, loss_p -0.8508, cov_diff 0.7814639736118612
# Epoch: 31, iteration 1, loss -2.2399, loss_p -0.8508, cov_diff 0.782166307166932
# Epoch: 31, iteration 2, loss -2.2474, loss_p -0.8508, cov_diff 0.7673330319921975
# Epoch: 31, iteration 3, loss -2.2599, loss_p -0.8508, cov_diff 0.7861148891703866
# Epoch: 31, iteration 4, loss -2.1206, loss_p -0.8508, cov_diff 0.7711001549458443
# Epoch: 31, iteration 5, loss -2.2653, loss_p -0.8508, cov_diff 0.7790828801103393
# Epoch: 31, iteration 6, loss -2.2944, loss_p -0.8508, cov_diff 0.7790736197724812
# Epoch: 31, iteration 7, loss -2.2290, loss_p -0.8508, cov_diff 0.7732862591439464
# Epoch: 31, iteration 8, loss -2.1098, loss_p -0.8508, cov_diff 0.777857223635247
# Epoch: 31, iteration 9, loss -2.2514, loss_p -0.8508, cov_diff 0.775158783721698
# Epoch: 31, iteration 10, loss -2.3521, loss_p -0.8508, cov_diff 0.7850811633284864
# Epoch: 31, iteration 11, loss -2.2695, loss_p -0.8508, cov_diff 0.7822191375499566
# Epoch: 31, iteration 12, loss -2.2590, loss_p -0.8508, cov_diff 0.770983427895068
# Epoch: 31, iteration 13, loss -2.2815, loss_p -0.8508, cov_diff 0.7747246109269105
# Epoch: 31, iteration 14, loss -2.3118, loss_p -0.8508, cov_diff 0.7859827841689474
# Epoch: 31, iteration 15, loss -2.2047, loss_p -0.8508, cov_diff 0.772334987091827
# Epoch: 31, iteration 16, loss -2.2348, loss_p -0.8508, cov_diff 0.7802067036240992
# Epoch: 31, iteration 17, loss -2.4295, loss_p -0.8508, cov_diff 0.7777938253389449
# Epoch: 31, iteration 18, loss -2.4187, loss_p -0.8508, cov_diff 0.7768180562571428
# Epoch: 31, iteration 19, loss -2.2686, loss_p -0.8508, cov_diff 0.7782647110266327
# Generator step
# Epoch: 31, iteration 20, loss -2.3866, loss_p -0.8260, cov_diff 0.7687762300565344
# Epoch: 31, iteration 21, loss -2.3448, loss_p -0.8260, cov_diff 0.7739482224232498
# Epoch: 31, iteration 22, loss -2.2236, loss_p -0.8260, cov_diff 0.7775905150836122
# Epoch: 31, iteration 23, loss -2.3188, loss_p -0.8260, cov_diff 0.784286380473863
# Epoch: 31, iteration 24, loss -2.3303, loss_p -0.8260, cov_diff 0.7712217748907239
# Epoch: 31, iteration 25, loss -2.2664, loss_p -0.8260, cov_diff 0.7764210065168503
# Epoch: 31, iteration 26, loss -2.2498, loss_p -0.8260, cov_diff 0.7757787925079833
# Epoch: 31, iteration 27, loss -2.3101, loss_p -0.8260, cov_diff 0.772176064855672
# Epoch: 31, iteration 28, loss -2.3254, loss_p -0.8260, cov_diff 0.7666826020472243
# Epoch: 31, iteration 29, loss -2.2942, loss_p -0.8260, cov_diff 0.7732050024144584
# Epoch: 31, iteration 30, loss -2.2307, loss_p -0.8260, cov_diff 0.759956341267504
# Epoch: 31, iteration 31, loss -2.1886, loss_p -0.8260, cov_diff 0.7768819031782964
# Epoch: 31, iteration 32, loss -2.1879, loss_p -0.8260, cov_diff 0.7716464210184325
# Epoch: 31, iteration 33, loss -2.2612, loss_p -0.8260, cov_diff 0.778095291832919
# Epoch: 31, iteration 34, loss -2.2350, loss_p -0.8260, cov_diff 0.7759611229724056
# Epoch: 31, iteration 35, loss -2.2020, loss_p -0.8260, cov_diff 0.7821758569885745
# Epoch: 31, iteration 36, loss -2.1767, loss_p -0.8260, cov_diff 0.773555773271877
# Epoch: 31, iteration 37, loss -2.2962, loss_p -0.8260, cov_diff 0.7720419747657282
# Epoch: 31, iteration 38, loss -2.2579, loss_p -0.8260, cov_diff 0.7781951628259073
# Epoch: 31, iteration 39, loss -2.2464, loss_p -0.8260, cov_diff 0.7842557058334347
# Generator step
# Epoch: 31, iteration 40, loss -2.2112, loss_p -0.7859, cov_diff 0.7756741162982975
# Epoch: 31, iteration 41, loss -2.3218, loss_p -0.7859, cov_diff 0.7666587214733436
# Epoch: 31, iteration 42, loss -2.2625, loss_p -0.7859, cov_diff 0.7715883498762944
# Epoch: 31, iteration 43, loss -2.1891, loss_p -0.7859, cov_diff 0.768979246105391
# Epoch: 31, iteration 44, loss -2.3404, loss_p -0.7859, cov_diff 0.7616164470700664
# Epoch: 31, iteration 45, loss -2.2682, loss_p -0.7859, cov_diff 0.7674932522798683
# Epoch: 31, iteration 46, loss -2.2282, loss_p -0.7859, cov_diff 0.7760076028295726
# Epoch: 31, iteration 47, loss -2.3147, loss_p -0.7859, cov_diff 0.7726511287577846
# Epoch: 31, iteration 48, loss -2.1844, loss_p -0.7859, cov_diff 0.7713159637784244
# Epoch: 31, iteration 49, loss -2.2333, loss_p -0.7859, cov_diff 0.7626157297606301
# Epoch: 31, iteration 50, loss -2.2782, loss_p -0.7859, cov_diff 0.7651340612948392
# Epoch: 31, iteration 51, loss -2.3248, loss_p -0.7859, cov_diff 0.76224914832056
# Epoch: 31, iteration 52, loss -2.1986, loss_p -0.7859, cov_diff 0.7651792934656563
# Epoch: 31, iteration 53, loss -2.3716, loss_p -0.7859, cov_diff 0.7720261598318169
# Epoch: 31, iteration 54, loss -2.1907, loss_p -0.7859, cov_diff 0.7764168270790104
# Epoch: 31, iteration 55, loss -2.3281, loss_p -0.7859, cov_diff 0.7662021216138355
# Epoch: 31, iteration 56, loss -2.1975, loss_p -0.7859, cov_diff 0.7666040780362343
# Epoch: 31, iteration 57, loss -2.3245, loss_p -0.7859, cov_diff 0.7703040888793303
# Epoch: 31, iteration 58, loss -2.0958, loss_p -0.7859, cov_diff 0.7662551067760639
# Epoch: 31, iteration 59, loss -2.3439, loss_p -0.7859, cov_diff 0.7634913740758231
# Generator step
# Epoch: 31, iteration 60, loss -2.1555, loss_p -0.7188, cov_diff 0.7682116280237586
# Epoch: 31, iteration 61, loss -2.2378, loss_p -0.7188, cov_diff 0.7662621092778769
# Epoch: 31, iteration 62, loss -2.2221, loss_p -0.7188, cov_diff 0.7560893901068948
# Epoch: 31, iteration 63, loss -2.3000, loss_p -0.7188, cov_diff 0.7556836256489456
# Epoch: 31, iteration 64, loss -2.3313, loss_p -0.7188, cov_diff 0.7679068496435394
# Epoch: 31, iteration 65, loss -2.2953, loss_p -0.7188, cov_diff 0.7686664414208617
# Epoch: 31, iteration 66, loss -2.2111, loss_p -0.7188, cov_diff 0.7562868562878463
# Epoch: 31, iteration 67, loss -2.1843, loss_p -0.7188, cov_diff 0.7655000356233814
# Epoch: 31, iteration 68, loss -2.3136, loss_p -0.7188, cov_diff 0.7661282425947581
# Epoch: 31, iteration 69, loss -2.2349, loss_p -0.7188, cov_diff 0.7696554337110629
# Epoch: 31, iteration 70, loss -2.3463, loss_p -0.7188, cov_diff 0.7734538972436532
# Epoch: 31, iteration 71, loss -2.1907, loss_p -0.7188, cov_diff 0.7637032939159392
# Epoch: 31, iteration 72, loss -2.3265, loss_p -0.7188, cov_diff 0.7594869746453985
# Epoch: 31, iteration 73, loss -2.2124, loss_p -0.7188, cov_diff 0.7666900826211137
# Epoch: 31, iteration 74, loss -2.2800, loss_p -0.7188, cov_diff 0.7702468407575955
# Epoch: 31, iteration 75, loss -2.3079, loss_p -0.7188, cov_diff 0.758221382427301
# Epoch: 31, iteration 76, loss -2.2397, loss_p -0.7188, cov_diff 0.7694437705023329
# Epoch: 31, iteration 77, loss -2.2295, loss_p -0.7188, cov_diff 0.7707892212379462
# Epoch: 31, iteration 78, loss -2.2588, loss_p -0.7188, cov_diff 0.765554648615956
# Epoch: 31, iteration 79, loss -2.3179, loss_p -0.7188, cov_diff 0.763869322219925
# Generator step
# Epoch: 31, iteration 80, loss -2.3501, loss_p -0.8359, cov_diff 0.7665986711987759
# Epoch: 31, iteration 81, loss -2.3081, loss_p -0.8359, cov_diff 0.7673516713585421
# Epoch: 31, iteration 82, loss -2.3153, loss_p -0.8359, cov_diff 0.7601738140653324
# Epoch: 31, iteration 83, loss -2.3217, loss_p -0.8359, cov_diff 0.7584307056295689
# Epoch: 31, iteration 84, loss -2.3876, loss_p -0.8359, cov_diff 0.7541998839439202
# Epoch: 31, iteration 85, loss -2.1602, loss_p -0.8359, cov_diff 0.7730885657374379
# Epoch: 31, iteration 86, loss -2.2741, loss_p -0.8359, cov_diff 0.7772977144873432
# Epoch: 31, iteration 87, loss -2.2571, loss_p -0.8359, cov_diff 0.7517713763123943
# Epoch: 31, iteration 88, loss -2.3677, loss_p -0.8359, cov_diff 0.7594444693964493
# Epoch: 31, iteration 89, loss -2.2736, loss_p -0.8359, cov_diff 0.7615141230982216
# Epoch: 31, iteration 90, loss -2.1030, loss_p -0.8359, cov_diff 0.7635839930775544
# Epoch: 31, iteration 91, loss -2.2381, loss_p -0.8359, cov_diff 0.7577698932213975
# Epoch: 31, iteration 92, loss -2.1648, loss_p -0.8359, cov_diff 0.766566931863216
# Epoch: 31, iteration 93, loss -2.3949, loss_p -0.8359, cov_diff 0.764509869815301
# Epoch: 31, iteration 94, loss -2.2703, loss_p -0.8359, cov_diff 0.7609186585486672
# Epoch: 31, iteration 95, loss -2.2353, loss_p -0.8359, cov_diff 0.7508423634125376
# Epoch: 31, iteration 96, loss -2.1684, loss_p -0.8359, cov_diff 0.7681775179820387
# Epoch: 31, iteration 97, loss -2.3502, loss_p -0.8359, cov_diff 0.7613404517205156
# Epoch: 31, iteration 98, loss -2.3745, loss_p -0.8359, cov_diff 0.7586521995094374
# Epoch: 31, iteration 99, loss -2.2917, loss_p -0.8359, cov_diff 0.7556004768484897
# Generator step
# Epoch: 31, iteration 100, loss -2.2618, loss_p -0.8435, cov_diff 0.7657375749204697
# Epoch: 31, iteration 101, loss -2.2906, loss_p -0.8435, cov_diff 0.7641903815024277
# Epoch: 31, iteration 102, loss -2.1420, loss_p -0.8435, cov_diff 0.764556474434454
# Epoch: 31, iteration 103, loss -2.2942, loss_p -0.8435, cov_diff 0.7587752144150847
# Epoch: 31, iteration 104, loss -2.3077, loss_p -0.8435, cov_diff 0.7551473762267602
# Epoch: 31, iteration 105, loss -2.2802, loss_p -0.8435, cov_diff 0.7593228013574151
# Epoch: 31, iteration 106, loss -2.1587, loss_p -0.8435, cov_diff 0.765987801969335
# Epoch: 31, iteration 107, loss -2.1371, loss_p -0.8435, cov_diff 0.7529363791294534
# Epoch: 31, iteration 108, loss -2.1451, loss_p -0.8435, cov_diff 0.7580132716875798
# Epoch: 31, iteration 109, loss -2.2531, loss_p -0.8435, cov_diff 0.7507931931706089
# Epoch: 31, iteration 110, loss -2.2659, loss_p -0.8435, cov_diff 0.7626164127027699
# Epoch: 31, iteration 111, loss -2.3867, loss_p -0.8435, cov_diff 0.7596693692107698
# Epoch: 31, iteration 112, loss -2.2847, loss_p -0.8435, cov_diff 0.7678652166839708
# Epoch: 31, iteration 113, loss -2.1699, loss_p -0.8435, cov_diff 0.7661591928638597
# Epoch: 31, iteration 114, loss -2.2047, loss_p -0.8435, cov_diff 0.7494969854323773
# Epoch: 31, iteration 115, loss -2.2576, loss_p -0.8435, cov_diff 0.7582978343706689
# Epoch: 31, iteration 116, loss -2.2326, loss_p -0.8435, cov_diff 0.7475001873018633
# Epoch: 31, iteration 117, loss -2.1471, loss_p -0.8435, cov_diff 0.752298907641171
# Epoch: 31, iteration 118, loss -2.3079, loss_p -0.8435, cov_diff 0.7608322545070357
# Epoch: 31, iteration 119, loss -2.1607, loss_p -0.8435, cov_diff 0.7564627442813124
# Generator step
# Epoch: 31, iteration 120, loss -2.2966, loss_p -0.8138, cov_diff 0.7580474753599926
# Epoch: 31, iteration 121, loss -2.2299, loss_p -0.8138, cov_diff 0.764825813787172
# Epoch: 31, iteration 122, loss -2.2865, loss_p -0.8138, cov_diff 0.7495211471177399
# Epoch: 31, iteration 123, loss -2.3461, loss_p -0.8138, cov_diff 0.7564234846387958
# Epoch: 31, iteration 124, loss -2.2599, loss_p -0.8138, cov_diff 0.7543326687943561
# Epoch: 31, iteration 125, loss -2.2743, loss_p -0.8138, cov_diff 0.7589123194347055
# Epoch: 31, iteration 126, loss -2.2481, loss_p -0.8138, cov_diff 0.7631549492333208
# Epoch: 31, iteration 127, loss -2.1600, loss_p -0.8138, cov_diff 0.7484038789373506
# Epoch: 31, iteration 128, loss -2.2943, loss_p -0.8138, cov_diff 0.7583988330768068
# Epoch: 31, iteration 129, loss -2.2459, loss_p -0.8138, cov_diff 0.7508069235313142
# Epoch: 31, iteration 130, loss -2.1805, loss_p -0.8138, cov_diff 0.764407090956741
# Epoch: 31, iteration 131, loss -2.3518, loss_p -0.8138, cov_diff 0.748832868970795
# Epoch: 31, iteration 132, loss -2.3799, loss_p -0.8138, cov_diff 0.7587360892653447
# Epoch: 31, iteration 133, loss -2.2986, loss_p -0.8138, cov_diff 0.7481755865696652
# Epoch: 31, iteration 134, loss -2.2564, loss_p -0.8138, cov_diff 0.7579333773325602
# Epoch: 31, iteration 135, loss -2.2414, loss_p -0.8138, cov_diff 0.7523229607899247
# Epoch: 31, iteration 136, loss -2.1682, loss_p -0.8138, cov_diff 0.7546810909001865
# Epoch: 31, iteration 137, loss -2.4380, loss_p -0.8138, cov_diff 0.7569629799139763
# Epoch: 31, iteration 138, loss -2.2584, loss_p -0.8138, cov_diff 0.7509292876708115
# Epoch: 31, iteration 139, loss -2.3721, loss_p -0.8138, cov_diff 0.7532379648756375
# Generator step
# Epoch: 31, iteration 140, loss -2.1856, loss_p -0.7417, cov_diff 0.756097145700665
# Epoch: 31, iteration 141, loss -2.3450, loss_p -0.7417, cov_diff 0.7603158001779021
# Epoch: 31, iteration 142, loss -2.2609, loss_p -0.7417, cov_diff 0.7643763638858802
# Epoch: 31, iteration 143, loss -2.2311, loss_p -0.7417, cov_diff 0.7703481302798543
# Epoch: 31, iteration 144, loss -2.1645, loss_p -0.7417, cov_diff 0.7606410998632911
# Epoch: 31, iteration 145, loss -2.0951, loss_p -0.7417, cov_diff 0.760226192474456
# Epoch: 31, iteration 146, loss -2.1488, loss_p -0.7417, cov_diff 0.7505258827527698
# Epoch: 31, iteration 147, loss -2.3236, loss_p -0.7417, cov_diff 0.7569532414649685
# Epoch: 31, iteration 148, loss -2.3225, loss_p -0.7417, cov_diff 0.739038123576821
# Epoch: 31, iteration 149, loss -2.1896, loss_p -0.7417, cov_diff 0.7529085972207107
# Epoch: 31, iteration 150, loss -2.2080, loss_p -0.7417, cov_diff 0.7548004942702874
# Epoch: 31, iteration 151, loss -2.2254, loss_p -0.7417, cov_diff 0.7630757116945381
# Epoch: 31, iteration 152, loss -2.2466, loss_p -0.7417, cov_diff 0.7577589398525021
# Epoch: 31, iteration 153, loss -2.3582, loss_p -0.7417, cov_diff 0.7627575790146794
# Epoch: 31, iteration 154, loss -2.2897, loss_p -0.7417, cov_diff 0.756296649580661
# Epoch: 31, iteration 155, loss -2.2339, loss_p -0.7417, cov_diff 0.7588373529129837
# Epoch: 31, iteration 156, loss -2.4624, loss_p -0.7417, cov_diff 0.7657895448138764
# Epoch: 31, iteration 157, loss -2.2599, loss_p -0.7417, cov_diff 0.7572348826258603
# Epoch: 31, iteration 158, loss -2.2473, loss_p -0.7417, cov_diff 0.7558971314590675
# Epoch: 31, iteration 159, loss -2.2384, loss_p -0.7417, cov_diff 0.7644481071824535
# Generator step
# Epoch: 31, iteration 160, loss -2.3659, loss_p -0.8161, cov_diff 0.7535157288702008
# Epoch: 31, iteration 161, loss -2.2072, loss_p -0.8161, cov_diff 0.768700131149606
# Epoch: 31, iteration 162, loss -2.4261, loss_p -0.8161, cov_diff 0.7631448923942608
# Epoch: 31, iteration 163, loss -2.4341, loss_p -0.8161, cov_diff 0.7690196596207861
# Epoch: 31, iteration 164, loss -2.2214, loss_p -0.8161, cov_diff 0.7630241862434304
# Epoch: 31, iteration 165, loss -2.1272, loss_p -0.8161, cov_diff 0.7646048924620286
# Epoch: 31, iteration 166, loss -2.1503, loss_p -0.8161, cov_diff 0.7596484619856751
# Epoch: 31, iteration 167, loss -2.2758, loss_p -0.8161, cov_diff 0.7595932549396107
# Epoch: 31, iteration 168, loss -2.2983, loss_p -0.8161, cov_diff 0.7592104923150523
# Epoch: 31, iteration 169, loss -2.2926, loss_p -0.8161, cov_diff 0.7613883679468341
# Epoch: 31, iteration 170, loss -2.2638, loss_p -0.8161, cov_diff 0.7624463976760383
# Epoch: 31, iteration 171, loss -2.1682, loss_p -0.8161, cov_diff 0.7588841775082015
# Epoch: 31, iteration 172, loss -2.3166, loss_p -0.8161, cov_diff 0.7609658538836819
# Epoch: 31, iteration 173, loss -2.2108, loss_p -0.8161, cov_diff 0.7600180410248986
# Epoch: 31, iteration 174, loss -2.2404, loss_p -0.8161, cov_diff 0.7594116691330476
# Epoch: 31, iteration 175, loss -2.3096, loss_p -0.8161, cov_diff 0.7583820690836452
# Epoch: 31, iteration 176, loss -2.3059, loss_p -0.8161, cov_diff 0.76251221950391
# Epoch: 31, iteration 177, loss -2.4062, loss_p -0.8161, cov_diff 0.7555716974102668
# Epoch: 31, iteration 178, loss -2.2493, loss_p -0.8161, cov_diff 0.7521142109089597
# ...
# Epoch: 39, iteration 202, loss -2.3027, loss_p -0.9218, cov_diff 0.7662502226766595
# Epoch: 39, iteration 203, loss -2.3048, loss_p -0.9218, cov_diff 0.7528707749869219
# Epoch: 39, iteration 204, loss -2.2095, loss_p -0.9218, cov_diff 0.7602262490072779
# Epoch: 39, iteration 205, loss -2.2588, loss_p -0.9218, cov_diff 0.7645471262653983
# Epoch: 39, iteration 206, loss -2.1940, loss_p -0.9218, cov_diff 0.765531746232017
# Epoch: 39, iteration 207, loss -2.2266, loss_p -0.9218, cov_diff 0.7677059452343714
# Epoch: 39, iteration 208, loss -2.0863, loss_p -0.9218, cov_diff 0.7614405085250439
# Epoch: 39, iteration 209, loss -2.2427, loss_p -0.9218, cov_diff 0.7621445498011473
# Epoch: 39, iteration 210, loss -2.3547, loss_p -0.9218, cov_diff 0.7606384396988336
# Epoch: 39, iteration 211, loss -2.2978, loss_p -0.9218, cov_diff 0.762580121991001
# Epoch: 39, iteration 212, loss -2.3255, loss_p -0.9218, cov_diff 0.7648094039558653
# Epoch: 39, iteration 213, loss -2.2019, loss_p -0.9218, cov_diff 0.760985614633769
# Epoch: 39, iteration 214, loss -2.1164, loss_p -0.9218, cov_diff 0.7584001607455795
# Epoch: 39, iteration 215, loss -2.2816, loss_p -0.9218, cov_diff 0.7589726883677631
# Epoch: 39, iteration 216, loss -2.1788, loss_p -0.9218, cov_diff 0.7610512006094031
# Epoch: 39, iteration 217, loss -2.1801, loss_p -0.9218, cov_diff 0.758924342300095
# Epoch: 39, iteration 218, loss -2.1916, loss_p -0.9218, cov_diff 0.7569164009909856
# Epoch: 39, iteration 219, loss -2.0818, loss_p -0.9218, cov_diff 0.761928787837326
# Generator step
# Epoch: 39, iteration 220, loss -2.2305, loss_p -0.8404, cov_diff 0.7619316435133755
# Epoch: 39, iteration 221, loss -2.3843, loss_p -0.8404, cov_diff 0.7538025032527458
# Epoch: 39, iteration 222, loss -2.2525, loss_p -0.8404, cov_diff 0.759456673943412
# Epoch: 39, iteration 223, loss -2.1849, loss_p -0.8404, cov_diff 0.7631188800901134
# Epoch: 39, iteration 224, loss -2.2867, loss_p -0.8404, cov_diff 0.7622761007112501
# Epoch: 39, iteration 225, loss -2.2145, loss_p -0.8404, cov_diff 0.7647352362880063
# Epoch: 39, iteration 226, loss -2.1416, loss_p -0.8404, cov_diff 0.7614570918652639
# Epoch: 39, iteration 227, loss -2.1908, loss_p -0.8404, cov_diff 0.761053706661611
# Epoch: 39, iteration 228, loss -2.1307, loss_p -0.8404, cov_diff 0.7476648915627412
# Epoch: 39, iteration 229, loss -2.3521, loss_p -0.8404, cov_diff 0.754835150377187
# Epoch: 39, iteration 230, loss -2.3592, loss_p -0.8404, cov_diff 0.7617467207313265
# Epoch: 39, iteration 231, loss -2.2834, loss_p -0.8404, cov_diff 0.7597301758365864
# Epoch: 39, iteration 232, loss -2.2668, loss_p -0.8404, cov_diff 0.7590571408577598
# Epoch: 39, iteration 233, loss -2.2551, loss_p -0.8404, cov_diff 0.7619618801148113
# Epoch: 39, iteration 234, loss -2.1821, loss_p -0.8404, cov_diff 0.7526919604452347
# Epoch: 39, iteration 235, loss -2.2543, loss_p -0.8404, cov_diff 0.7626486603298012
# Epoch: 39, iteration 236, loss -2.2619, loss_p -0.8404, cov_diff 0.7690839446862899
# Epoch: 39, iteration 237, loss -2.2457, loss_p -0.8404, cov_diff 0.7547479660703302
# Epoch: 39, iteration 238, loss -2.3712, loss_p -0.8404, cov_diff 0.7536031549859672
# Epoch: 39, iteration 239, loss -2.1408, loss_p -0.8404, cov_diff 0.761383766167576
# Generator step
# Epoch: 39, iteration 240, loss -2.2790, loss_p -0.9265, cov_diff 0.7576353029455383
# Epoch: 39, iteration 241, loss -2.1733, loss_p -0.9265, cov_diff 0.7568317871458905
# Epoch: 39, iteration 242, loss -2.2818, loss_p -0.9265, cov_diff 0.7571387366410628
# Epoch: 39, iteration 243, loss -2.2468, loss_p -0.9265, cov_diff 0.7558459788630663
# Epoch: 39, iteration 244, loss -2.2378, loss_p -0.9265, cov_diff 0.7566011809195665
# Epoch: 39, iteration 245, loss -2.4294, loss_p -0.9265, cov_diff 0.7493764884538022
# Epoch: 39, iteration 246, loss -2.2702, loss_p -0.9265, cov_diff 0.7558236186909215
# Epoch: 39, iteration 247, loss -2.1938, loss_p -0.9265, cov_diff 0.7547043131888075
# Epoch: 39, iteration 248, loss -2.3287, loss_p -0.9265, cov_diff 0.7525631392474236
# Epoch: 39, iteration 249, loss -1.9940, loss_p -0.9265, cov_diff 0.753970134835002
# Epoch: 39, iteration 250, loss -2.2638, loss_p -0.9265, cov_diff 0.7586913398641283
# Epoch: 39, iteration 251, loss -2.3540, loss_p -0.9265, cov_diff 0.7562009251125773
# Epoch: 39, iteration 252, loss -2.2642, loss_p -0.9265, cov_diff 0.7547549431266303
# Epoch: 39, iteration 253, loss -2.1751, loss_p -0.9265, cov_diff 0.7571460230074869
# Epoch: 39, iteration 254, loss -2.2311, loss_p -0.9265, cov_diff 0.757752058596788
# Epoch: 39, iteration 255, loss -2.3040, loss_p -0.9265, cov_diff 0.7672797033098447
# Epoch: 39, iteration 256, loss -2.1349, loss_p -0.9265, cov_diff 0.749974882688675
# Epoch: 39, iteration 257, loss -2.1996, loss_p -0.9265, cov_diff 0.752923346629856
# Epoch: 39, iteration 258, loss -2.1799, loss_p -0.9265, cov_diff 0.7456269059537887
# Epoch: 39, iteration 259, loss -2.2375, loss_p -0.9265, cov_diff 0.7566902261637247
# Generator step
# Epoch: 39, iteration 260, loss -2.2491, loss_p -0.7824, cov_diff 0.7617526942087832
# Epoch: 39, iteration 261, loss -2.2361, loss_p -0.7824, cov_diff 0.7497256950456106
# Epoch: 39, iteration 262, loss -2.3053, loss_p -0.7824, cov_diff 0.748390121528372
# Epoch: 39, iteration 263, loss -2.2691, loss_p -0.7824, cov_diff 0.7503413122259563
# Epoch: 39, iteration 264, loss -2.1291, loss_p -0.7824, cov_diff 0.7495684567717426
# Epoch: 39, iteration 265, loss -2.3487, loss_p -0.7824, cov_diff 0.7543464117906984
# Epoch: 39, iteration 266, loss -2.2537, loss_p -0.7824, cov_diff 0.7567015937274598
# Epoch: 39, iteration 267, loss -2.2525, loss_p -0.7824, cov_diff 0.7542317626670592
# Epoch: 39, iteration 268, loss -2.3481, loss_p -0.7824, cov_diff 0.7457702006491397
# Epoch: 39, iteration 269, loss -2.1122, loss_p -0.7824, cov_diff 0.7444304335122043
# Epoch: 39, iteration 270, loss -2.2743, loss_p -0.7824, cov_diff 0.7513701111712033
# Epoch: 39, iteration 271, loss -2.2261, loss_p -0.7824, cov_diff 0.7562853008323389
# Epoch: 39, iteration 272, loss -2.2705, loss_p -0.7824, cov_diff 0.7561483691786226
# Epoch: 39, iteration 273, loss -2.2553, loss_p -0.7824, cov_diff 0.7499614637718556
# Epoch: 39, iteration 274, loss -2.2505, loss_p -0.7824, cov_diff 0.7521715700102696
# Epoch: 39, iteration 275, loss -2.2275, loss_p -0.7824, cov_diff 0.7560013882462562
# Epoch: 39, iteration 276, loss -2.1651, loss_p -0.7824, cov_diff 0.7574671495126019
# Epoch: 39, iteration 277, loss -2.3511, loss_p -0.7824, cov_diff 0.7463628479776633
# Epoch: 39, iteration 278, loss -2.3186, loss_p -0.7824, cov_diff 0.7450693507095785
# Epoch: 39, iteration 279, loss -2.3910, loss_p -0.7824, cov_diff 0.7570553638605767
# Generator step
# Epoch: 39, iteration 280, loss -2.2677, loss_p -0.8721, cov_diff 0.752301955790362
# Epoch: 39, iteration 281, loss -2.2926, loss_p -0.8721, cov_diff 0.7474084773168753
# Epoch: 39, iteration 282, loss -2.1866, loss_p -0.8721, cov_diff 0.7464543062705163
# Epoch: 39, iteration 283, loss -2.2770, loss_p -0.8721, cov_diff 0.7458491872877991
# Epoch: 39, iteration 284, loss -2.1751, loss_p -0.8721, cov_diff 0.7480316138593849
# Epoch: 39, iteration 285, loss -2.2497, loss_p -0.8721, cov_diff 0.7523648361209179
# Epoch: 39, iteration 286, loss -2.3431, loss_p -0.8721, cov_diff 0.7481330501816377
# Epoch: 39, iteration 287, loss -2.3031, loss_p -0.8721, cov_diff 0.7579364579613539
# Epoch: 39, iteration 288, loss -2.3078, loss_p -0.8721, cov_diff 0.7582566981056785
# Epoch: 39, iteration 289, loss -2.1190, loss_p -0.8721, cov_diff 0.758913338274164
# Epoch: 39, iteration 290, loss -2.3644, loss_p -0.8721, cov_diff 0.7515996739108908
# Epoch: 39, iteration 291, loss -2.2098, loss_p -0.8721, cov_diff 0.7444377847354321
# Epoch: 39, iteration 292, loss -2.2611, loss_p -0.8721, cov_diff 0.7542532374616391
# Epoch: 39, iteration 293, loss -2.3593, loss_p -0.8721, cov_diff 0.7499293944108203
# Epoch: 39, iteration 294, loss -2.3711, loss_p -0.8721, cov_diff 0.7556505790638264
# Epoch: 39, iteration 295, loss -2.2294, loss_p -0.8721, cov_diff 0.743037472371964
# Epoch: 39, iteration 296, loss -2.2580, loss_p -0.8721, cov_diff 0.7535695902484386
# Epoch: 39, iteration 297, loss -2.3162, loss_p -0.8721, cov_diff 0.7452017353414968
# Epoch: 39, iteration 298, loss -2.3417, loss_p -0.8721, cov_diff 0.7609815137333464
# Epoch: 39, iteration 299, loss -2.1842, loss_p -0.8721, cov_diff 0.7532603017548195
# Generator step
# Epoch: 39, iteration 300, loss -2.2527, loss_p -0.8656, cov_diff 0.7540085380542045
# Epoch: 39, iteration 301, loss -2.0661, loss_p -0.8656, cov_diff 0.7455771520856792
# Epoch: 39, iteration 302, loss -2.3490, loss_p -0.8656, cov_diff 0.7433201490398468
# Epoch: 39, iteration 303, loss -2.3504, loss_p -0.8656, cov_diff 0.7581477093351126
# Epoch: 39, iteration 304, loss -2.2402, loss_p -0.8656, cov_diff 0.7506166862468348
# Epoch: 39, iteration 305, loss -2.2744, loss_p -0.8656, cov_diff 0.7542279970256736
# Epoch: 39, iteration 306, loss -2.2753, loss_p -0.8656, cov_diff 0.7499391572640932
# Epoch: 39, iteration 307, loss -2.3258, loss_p -0.8656, cov_diff 0.7460927246405312
# Epoch: 39, iteration 308, loss -2.3609, loss_p -0.8656, cov_diff 0.7534240777647385
# Epoch: 39, iteration 309, loss -2.1273, loss_p -0.8656, cov_diff 0.7372530817277315
# Epoch: 39, iteration 310, loss -2.3077, loss_p -0.8656, cov_diff 0.7532184429294835
# Epoch: 39, iteration 311, loss -2.2739, loss_p -0.8656, cov_diff 0.7506182812854756
# Epoch: 39, iteration 312, loss -2.1915, loss_p -0.8656, cov_diff 0.7414358414365775
# Epoch: 39, iteration 313, loss -2.3344, loss_p -0.8656, cov_diff 0.7496693474776727
# Epoch: 39, iteration 314, loss -2.2571, loss_p -0.8656, cov_diff 0.748509741744325
# Epoch: 39, iteration 315, loss -2.3285, loss_p -0.8656, cov_diff 0.7465543415640575
# Epoch: 39, iteration 316, loss -2.3675, loss_p -0.8656, cov_diff 0.7520635323874889
# Epoch: 39, iteration 317, loss -2.2499, loss_p -0.8656, cov_diff 0.7618644324632844
# Epoch: 39, iteration 318, loss -2.1041, loss_p -0.8656, cov_diff 0.7476013918012655
# Epoch: 39, iteration 319, loss -2.3175, loss_p -0.8656, cov_diff 0.743153426904879
# Generator step
# Epoch: 39, iteration 320, loss -2.3867, loss_p -0.9121, cov_diff 0.7509898433627327
# Epoch: 39, iteration 321, loss -2.2328, loss_p -0.9121, cov_diff 0.7507277886763052
# Epoch: 39, iteration 322, loss -2.2606, loss_p -0.9121, cov_diff 0.7532482060768664
# Epoch: 39, iteration 323, loss -2.3653, loss_p -0.9121, cov_diff 0.7504409614759473
# Epoch: 39, iteration 324, loss -2.2190, loss_p -0.9121, cov_diff 0.7471796675817519
# Epoch: 39, iteration 325, loss -2.1773, loss_p -0.9121, cov_diff 0.749416960370769
# Epoch: 39, iteration 326, loss -2.1705, loss_p -0.9121, cov_diff 0.7528467816434214
# Epoch: 39, iteration 327, loss -2.1896, loss_p -0.9121, cov_diff 0.7434194501878104
# Epoch: 39, iteration 328, loss -2.2144, loss_p -0.9121, cov_diff 0.7509805063743757
# Epoch: 39, iteration 329, loss -2.2112, loss_p -0.9121, cov_diff 0.7470629381175957
# Epoch: 39, iteration 330, loss -2.1511, loss_p -0.9121, cov_diff 0.7583490833774194
# Epoch: 39, iteration 331, loss -2.2989, loss_p -0.9121, cov_diff 0.7622254479694219
# Epoch: 39, iteration 332, loss -2.3081, loss_p -0.9121, cov_diff 0.7463438317239282
# Epoch: 39, iteration 333, loss -2.3993, loss_p -0.9121, cov_diff 0.7565999140561435
# Epoch: 39, iteration 334, loss -2.2675, loss_p -0.9121, cov_diff 0.7473236723489949
# Epoch: 39, iteration 335, loss -2.2005, loss_p -0.9121, cov_diff 0.7507173120665399
# Epoch: 39, iteration 336, loss -2.3373, loss_p -0.9121, cov_diff 0.7526189260489324
# Epoch: 39, iteration 337, loss -2.2328, loss_p -0.9121, cov_diff 0.7514318264049069
# Epoch: 39, iteration 338, loss -2.2905, loss_p -0.9121, cov_diff 0.7435341161564359
# Epoch: 39, iteration 339, loss -2.2431, loss_p -0.9121, cov_diff 0.7583287851007451
# Generator step
# Epoch: 39, iteration 340, loss -2.1355, loss_p -0.7638, cov_diff 0.7496975805156068
# Epoch: 39, iteration 341, loss -2.2980, loss_p -0.7638, cov_diff 0.7503621129992406
# Epoch: 39, iteration 342, loss -2.1159, loss_p -0.7638, cov_diff 0.7526267086684866
# Epoch: 39, iteration 343, loss -2.3719, loss_p -0.7638, cov_diff 0.7492451089427797
# Epoch: 39, iteration 344, loss -2.1993, loss_p -0.7638, cov_diff 0.7447183648798007
# Epoch: 39, iteration 345, loss -2.3028, loss_p -0.7638, cov_diff 0.7421638448484682
# Epoch: 39, iteration 346, loss -2.2412, loss_p -0.7638, cov_diff 0.7580594837372644
# Epoch: 39, iteration 347, loss -2.1854, loss_p -0.7638, cov_diff 0.7526392860433861
# Epoch: 39, iteration 348, loss -2.2879, loss_p -0.7638, cov_diff 0.7518518581359214
# Epoch: 39, iteration 349, loss -2.2185, loss_p -0.7638, cov_diff 0.7530229039760785
# Epoch: 39, iteration 350, loss -2.1945, loss_p -0.7638, cov_diff 0.7560141786482388
# Epoch: 39, iteration 351, loss -2.2895, loss_p -0.7638, cov_diff 0.7544162570358871
# Epoch: 39, iteration 352, loss -2.2446, loss_p -0.7638, cov_diff 0.7520760792601119
# Epoch: 39, iteration 353, loss -2.3893, loss_p -0.7638, cov_diff 0.7534858986927649
# Epoch: 39, iteration 354, loss -2.3013, loss_p -0.7638, cov_diff 0.7570325470195197
# Epoch: 39, iteration 355, loss -2.2386, loss_p -0.7638, cov_diff 0.7554638186872705
# Epoch: 39, iteration 356, loss -2.2353, loss_p -0.7638, cov_diff 0.74184236768079
# Epoch: 39, iteration 357, loss -2.2310, loss_p -0.7638, cov_diff 0.7542200186357931
# Epoch: 39, iteration 358, loss -2.3790, loss_p -0.7638, cov_diff 0.7475988000758254
# Epoch: 39, iteration 359, loss -2.1791, loss_p -0.7638, cov_diff 0.7596163042647899
# Generator step
# Epoch: 39, iteration 360, loss -2.2438, loss_p -0.8044, cov_diff 0.7523985194871098
# Epoch: 39, iteration 361, loss -2.2380, loss_p -0.8044, cov_diff 0.7662313823064779
# Epoch: 39, iteration 362, loss -2.3104, loss_p -0.8044, cov_diff 0.7602990954111395
# Epoch: 39, iteration 363, loss -2.1547, loss_p -0.8044, cov_diff 0.7532424891811333
# Epoch: 39, iteration 364, loss -2.1853, loss_p -0.8044, cov_diff 0.7568674893439327
# Epoch: 39, iteration 365, loss -2.0937, loss_p -0.8044, cov_diff 0.7523901418737369
# Epoch: 39, iteration 366, loss -2.1854, loss_p -0.8044, cov_diff 0.750946086958287
# Epoch: 39, iteration 367, loss -2.1659, loss_p -0.8044, cov_diff 0.7518167850390052
# Epoch: 39, iteration 368, loss -2.1141, loss_p -0.8044, cov_diff 0.7582314870139428
# Epoch: 39, iteration 369, loss -2.1474, loss_p -0.8044, cov_diff 0.7597874084412194
# Epoch: 39, iteration 370, loss -2.2420, loss_p -0.8044, cov_diff 0.7550879412314733
# Epoch: 39, iteration 371, loss -2.2407, loss_p -0.8044, cov_diff 0.7627107058082672
# Epoch: 39, iteration 372, loss -2.2138, loss_p -0.8044, cov_diff 0.7524591020911747
# Epoch: 39, iteration 373, loss -2.2627, loss_p -0.8044, cov_diff 0.7531085067779004
# Epoch: 39, iteration 374, loss -2.2825, loss_p -0.8044, cov_diff 0.7614167788433219
# Epoch: 39, iteration 375, loss -2.1333, loss_p -0.8044, cov_diff 0.7644556802826655
# Epoch: 39, iteration 376, loss -2.2778, loss_p -0.8044, cov_diff 0.7547708133326776
# Epoch: 39, iteration 377, loss -2.2411, loss_p -0.8044, cov_diff 0.7559430829377237
# Epoch: 39, iteration 378, loss -2.1342, loss_p -0.8044, cov_diff 0.7617813963655634
# Epoch: 39, iteration 379, loss -2.3351, loss_p -0.8044, cov_diff 0.746105895489438
# Generator step
# Epoch: 39, iteration 380, loss -2.1120, loss_p -0.8655, cov_diff 0.7602089318508493
# Epoch: 39, iteration 381, loss -2.2665, loss_p -0.8655, cov_diff 0.7527521906585389
# Epoch: 39, iteration 382, loss -2.2649, loss_p -0.8655, cov_diff 0.7497922270121342
# Epoch: 39, iteration 383, loss -2.2654, loss_p -0.8655, cov_diff 0.7559636921726584
# Epoch: 39, iteration 384, loss -2.1864, loss_p -0.8655, cov_diff 0.7597507018939091
# Epoch: 39, iteration 385, loss -2.3840, loss_p -0.8655, cov_diff 0.752793328252973
# Epoch: 39, iteration 386, loss -2.2137, loss_p -0.8655, cov_diff 0.7548613490884626
# Epoch: 39, iteration 387, loss -2.2249, loss_p -0.8655, cov_diff 0.7615000848892038
# Epoch: 39, iteration 388, loss -2.2160, loss_p -0.8655, cov_diff 0.753892668643215
# Epoch: 39, iteration 389, loss -2.2313, loss_p -0.8655, cov_diff 0.7570723393686577
# Epoch: 39, iteration 390, loss -2.4592, loss_p -0.8655, cov_diff 0.761987723390143

# %%
plt.figure()
if MODE == 'divergence':
    model_name = "P_SINKHORN_LAMBDA_"#P = parametric
else:
    model_name = "P_ENTROPIC_LAMBDA_"
model_name = model_name +str(LAMBDA) + "_LATENT_DIM_" + str(LATENT_DIM) + "_initialization_" + INITIALIZATION
model_name = 'tmp_'+model_name

# %%
accuracy_history = np.array(acc_cov_diff)
step = 1
plt.clf()
plt.grid("on", "both")
idx = np.max(np.where(accuracy_history > 3.5))+1

iteration = len(acc_cov_diff)
plt.plot(np.arange(idx,iteration,step), accuracy_history[idx:], linewidth=2, color = 'red')
plt.plot(np.arange(iteration+1), np.zeros(iteration+1), linewidth=2, color = 'green')
#plt.savefig("./plots/accuracy_history_"+model_name+".png")
plt.show()

# %%
accuracy_history = np.array(acc_cov_diff[80:])
step = 1
plt.clf()
plt.grid("on", "both")
idx = np.max(np.where(accuracy_history > 2.5))+1

iteration = len(accuracy_history)
plt.plot(np.arange(idx,iteration,step), accuracy_history[idx:], linewidth=2, color = 'red')
plt.plot(np.arange(iteration+1), np.zeros(iteration+1), linewidth=2, color = 'green')
#plt.savefig("./plots/accuracy_history_"+model_name+".png")
plt.show()

# %%
np.max(np.where(accuracy_history > 3.5))
# Out:
# 0

# %%
with open('./training_process_dump/' + model_name + '.pkl', 'wb') as f:
    pkl.dump([res,acc_cov_diff], f)

# %%
plt.plot(np.minimum(cov_diff_all, 0.6))

# %%
plt.plot(np.minimum(cov_diff_all, 0.6))#Df,Dr(lr=0.005), Dff(lr=0.01) -- RMSProp, G -- Adam(lr = 0.005)

# %%
plt.plot(cov_diff_all[500:])#Df,Dr(lr=0.005), Dff(lr=0.01) -- RMSProp, G -- Adam(lr = 0.005)

# %%
plt.plot(cov_diff_all[500:])#Df,Dr(lr=0.005), Dff(lr=0.01) -- RMSProp, G -- Adam(lr = 0.003)

# %%
plt.plot(cov_diff_all[500:])#Df,Dr(lr=0.01), Dff(lr=0.01) -- RMSProp, G -- Adam

# %%
plt.plot(cov_diff_all[500:])#Df,Dr(lr=default), Dff(lr=0.01) -- RMSProp, G -- Adam, no detach in D_ff

# %%
plt.plot(cov_diff_all[500:])#Df,Dr(lr=default), Dff(lr=0.01) -- RMSProp, G -- Adam

# %%
#plt.plot(cov_diff_all[500:])#Df,Dr(lr=default) -- Adam, Dff(lr=0.01) -- RMSProp, G -- Adam

# %%
losses = []
for epoch in res['loss']:
    losses += res['loss'][epoch]

# %%
plt.plot(losses[250:])
plt.legend(['disc 1,2','disc_ff','sinkh'])

# %%
plt.plot(losses[250:])
plt.legend(['disc 1,2','disc_ff','sinkh'])

# %%
#plt.plot(losses[250:])
#plt.legend(['disc 1,2','disc_ff','sinkh'])

# %%
a = [1,2,3]

# %%
a[1::1]
# Out:
# [2, 3]

# %%
# This code is heavily based on Jan Mentzen's implementation of a VAE (https://jmetzen.github.io/2015-11-27/vae.html)

import numpy as np
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import pickle as pkl

from torch.utils.data import Dataset, DataLoader
from torch.nn import Linear, ReLU, Module
from torch.nn.init import kaiming_uniform_, xavier_uniform_
import torch.nn as nn

np.random.seed(0)

import torch
import geomloss

from geomloss.utils import squared_distances

import argparse

# parser = argparse.ArgumentParser(description='Process args for GAN.')
# parser.add_argument('--weight_init', default = 'he')
# parser.add_argument('--latent_dim', type = int, default = 32)
# parser.add_argument('--lamb', type = float, default = .5)
# args = parser.parse_args()


DIM = 64 # Model dimensionality (number of neurons in the hidden layer(s))
CRITIC_ITERS = 5 # How many critic iterations (Sinkhorn iterations) per generator iteration#was 50
BATCH_SIZE = 256 # Batch size
EPOCHS = 1#55#100000 # how many generator iterations to train for
DATA_DIM = 32
LATENT_DIM = 8#args.latent_dim
INITIALIZATION = 'he'#args.weight_init#'glorot'
COVARIANCE_SCALE = np.sqrt(DATA_DIM)
INITIALIZE_LAST = True
SAMPLE_SIZE = 100000
LAMBDA = 2#args.lamb
MODE = "divergence"

def initializer(weight):
    if INITIALIZATION == 'he':
        return kaiming_uniform_(weight, nonlinearity='relu')
    if INITIALIZATION == 'glorot':
        return xavier_uniform_(weight)
    print("UNKNOWN INITIALIZATION")
    return None

def init_weights(m):
    if type(m) == nn.Linear:
        initializer(m.weight)
        
class GaussianDataset(Dataset):
    # reading the csv and defining predictor and output columns
    def __init__(self, sample_size=SAMPLE_SIZE, data_dim=DATA_DIM, latent_dim = LATENT_DIM,
                 variance = 1/COVARIANCE_SCALE):
    
        # store the input and output features
        
        np.random.seed(1)
        self.X = np.random.randn(sample_size,data_dim) * np.sqrt(variance)
        self.latent_dim = latent_dim
    
        # ensure all data is numerical - type(float)
        self.X = self.X.astype('float32')
    
    # number of rows in dataset
    def __len__(self):
        return len(self.X)
    
    # get a row at an index
    def __getitem__(self, index):
        return [np.random.randn(self.latent_dim).astype('float32'), self.X[index], 
                np.random.randn(self.latent_dim).astype('float32'), 
                np.random.randn(self.latent_dim).astype('float32')]
dataset = GaussianDataset()
data_dl = DataLoader(dataset, batch_size = BATCH_SIZE, shuffle = True)

class Generator(Module):
    def __init__(self, n_inputs = LATENT_DIM):
        super(Generator, self).__init__()

        self.model = nn.Sequential(        
        # defining the inputs to the first hidden layer
            Linear(n_inputs, DIM) ,
            ReLU(),
            Linear(DIM, DIM),
            ReLU(),
            Linear(DIM, DIM),
            ReLU(),
            Linear(DIM, DATA_DIM),
        )
        self.model.apply(init_weights)

    def forward(self, X):
        X = self.model(X)
        return X

class Discriminator(Module):
    def __init__(self, n_inputs = DATA_DIM):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(        
        # defining the inputs to the first hidden layer
            Linear(n_inputs, DIM) ,
            ReLU(),
            Linear(DIM, DIM),
            ReLU(),
            Linear(DIM, DIM),
            ReLU(),
            Linear(DIM, 1),
        )
        self.model.apply(init_weights)

    def forward(self, X):
        X = self.model(X)
        return X
    
# Initialize generator and discriminator
generator = Generator()
discriminator_fake = Discriminator() #for fake data (hat_Y) in W(Y, hat_Y)
discriminator_real = Discriminator() #for real data (Y) in W(Y, hat_Y)
discriminator_ff = Discriminator() #for fake data (hat_Y) in W(hat_Y, hat_Y)

# Optimizers
optimizer_G = torch.optim.Adam(generator.parameters(), lr = 0.003)
optimizer_Df = torch.optim.RMSprop(discriminator_fake.parameters(),lr=0.005)
optimizer_Dr = torch.optim.RMSprop(discriminator_real.parameters(),lr=0.005)
optimizer_Dff = torch.optim.RMSprop(discriminator_ff.parameters(), lr = 0.01)
#optimizer_Dr = torch.optim.RMSprop()
#optimizer_Dff = torch.optim.RMSprop(discriminator_ff.parameters())

eps = LAMBDA
def sinkhorn_loss_dual(dual_fake, dual_real, cost_mat):#this is a negative loss
    log_pi = (dual_real.T+dual_fake - cost_mat)/eps
    reg_term = (log_pi).logsumexp((0,1))
    W_neg = - dual_fake.mean() - dual_real.mean() + eps*reg_term 
    return W_neg

res = {'loss':{}, 'sample': {}, 'cov_diff' : {}}
res['lambda'] = LAMBDA
cov_diff_all = []
epochs = EPOCHS


acc_cov_diff = []

cov_diff_inp = torch.tensor(np.random.randn(10*BATCH_SIZE, LATENT_DIM).astype('float32'))


epochs_passed = len(list(res['loss'].keys()))#to continue training 
loss_G = 0
for epoch in range(epochs_passed, epochs_passed+epochs):
    if epoch == 15:
            optimizer_G.param_groups[0]['lr'] = 0.001
    if epoch == 25:
            optimizer_G.param_groups[0]['lr'] = 0.0007
    if epoch == 35:
            optimizer_G.param_groups[0]['lr'] = 0.0005
            optimizer_Df.param_groups[0]['lr'] = 0.0025
            optimizer_Dr.param_groups[0]['lr'] = 0.0025
            optimizer_Dff.param_groups[0]['lr'] = 0.005
    for key in res:
        if key != 'lambda':
            res[key][epoch] = []
    # go through all the batches generated by dataloader
    for i, (inputs, real_sample, inputs0, inputs1) in enumerate(data_dl):
        # clear the gradients
        optimizer_Dr.zero_grad()
        optimizer_Df.zero_grad()
        optimizer_Dff.zero_grad()
        
        # compute the discriminator model outputs & update
        fake_sample = generator(inputs)
        
        cov_diff = np.linalg.norm(np.cov(np.array(fake_sample.data).T) - np.eye(DATA_DIM)/COVARIANCE_SCALE)
        cost_mat = squared_distances(fake_sample, real_sample)
        dual_fake = discriminator_fake(fake_sample)
        dual_real = discriminator_real(real_sample)
        loss_dual = sinkhorn_loss_dual(dual_fake, dual_real, cost_mat)
        loss_dual.backward()
        optimizer_Dr.step()
        optimizer_Df.step()
        
        #Sinkhorn negentropy update
        fake_sample0 = generator(inputs0)
        fake_sample1 = generator(inputs1)
        cost_mat_ff = squared_distances(fake_sample0, fake_sample1)
        dual_ff0 = discriminator_ff(fake_sample0)
        dual_ff1 = discriminator_ff(fake_sample1)
        loss_dual_f = sinkhorn_loss_dual(dual_ff0, dual_ff1, cost_mat_ff)
        loss_dual_f.backward()
        optimizer_Dff.step()
        
        if i % CRITIC_ITERS == 0 and i>0:
            # -----------------
            #  Train Generator
            # -----------------
            print("Generator step")
            optimizer_G.zero_grad()
            
            fake_sample = generator(inputs)
            cost_mat = squared_distances(fake_sample, real_sample)
            dual_fake = discriminator_fake(fake_sample)
            dual_real = discriminator_real(real_sample)
            loss_dual = sinkhorn_loss_dual(dual_fake, dual_real, cost_mat)
            fake_sample0 = generator(inputs0)
            fake_sample1 = generator(inputs1)
            cost_mat_ff = squared_distances(fake_sample0, fake_sample1)
            dual_ff0 = discriminator_ff(fake_sample0)
            dual_ff1 = discriminator_ff(fake_sample1)
            loss_dual_f = sinkhorn_loss_dual(dual_ff0, dual_ff1, cost_mat_ff)
            
            loss_G = - loss_dual + 0.5*loss_dual_f
            loss_G.backward()
            optimizer_G.step()
        if i % 50 == 0:
            fake_sample = generator(cov_diff_inp)
            acc_cov_diff += [np.linalg.norm(np.cov(np.array(fake_sample.data).T) - 
                                      np.eye(DATA_DIM)/COVARIANCE_SCALE)]
            
        print("Epoch: {}, iteration {}, loss {:.4f}, loss_f {:.4f}, , loss_G {:.4f}, cov_diff {}".format(epoch,
                                                                                        i, loss_dual, 
                                                                                       loss_dual_f, loss_G, 
                                                                                       cov_diff))
        res['loss'][epoch].append([loss_dual, loss_dual_f, loss_G])
        res['sample'][epoch].append(np.array(fake_sample.data))
        res['cov_diff'][epoch].append(cov_diff)
    cov_diff_all += res['cov_diff'][epoch]
    
if MODE == 'divergence':
    model_name = "P_SINKHORN_LAMBDA_"#P = parametric
else:
    model_name = "P_ENTROPIC_LAMBDA_"
model_name = model_name +str(LAMBDA) + "_LATENT_DIM_" + str(LATENT_DIM) + "_initialization_" + INITIALIZATION
# Out:
# Epoch: 0, iteration 0, loss 5.2622, loss_f 7.6322, , loss_G 0.0000, cov_diff 7.954428155107681
# Epoch: 0, iteration 1, loss -4.8521, loss_f 706.0950, , loss_G 0.0000, cov_diff 6.389832831299533
# Epoch: 0, iteration 2, loss 25.8757, loss_f 215.9203, , loss_G 0.0000, cov_diff 6.5648098719527
# Epoch: 0, iteration 3, loss -14.1523, loss_f 10.9444, , loss_G 0.0000, cov_diff 6.333309625518603
# Epoch: 0, iteration 4, loss -20.5066, loss_f 19.1626, , loss_G 0.0000, cov_diff 7.471902113374785
# Generator step
# Epoch: 0, iteration 5, loss -16.7298, loss_f 8.9043, , loss_G 21.1819, cov_diff 7.239193255986548
# Epoch: 0, iteration 6, loss -3.3686, loss_f 7.8684, , loss_G 21.1819, cov_diff 6.391479358202467
# Epoch: 0, iteration 7, loss -10.5465, loss_f 7.5810, , loss_G 21.1819, cov_diff 5.981019173227736
# Epoch: 0, iteration 8, loss -11.4653, loss_f 8.0833, , loss_G 21.1819, cov_diff 5.553915836989004
# Epoch: 0, iteration 9, loss -11.9424, loss_f 8.5054, , loss_G 21.1819, cov_diff 5.826798522506025
# Generator step
# Epoch: 0, iteration 10, loss -10.8046, loss_f 8.8845, , loss_G 15.2469, cov_diff 5.510750481710087
# Epoch: 0, iteration 11, loss 0.3247, loss_f 9.1818, , loss_G 15.2469, cov_diff 4.032907887546504
# Epoch: 0, iteration 12, loss -2.5527, loss_f 9.0417, , loss_G 15.2469, cov_diff 3.8939114492481264
# Epoch: 0, iteration 13, loss -3.7507, loss_f 8.5909, , loss_G 15.2469, cov_diff 4.433719455103158
# Epoch: 0, iteration 14, loss -2.9635, loss_f 8.5569, , loss_G 15.2469, cov_diff 4.0524186948060725
# Generator step
# Epoch: 0, iteration 15, loss -4.1587, loss_f 8.5288, , loss_G 8.4232, cov_diff 4.4298720140090255
# Epoch: 0, iteration 16, loss 3.8659, loss_f 9.4778, , loss_G 8.4232, cov_diff 3.116282896119223
# Epoch: 0, iteration 17, loss 2.0850, loss_f 9.8726, , loss_G 8.4232, cov_diff 3.5053368232980606
# Epoch: 0, iteration 18, loss 2.0475, loss_f 10.0266, , loss_G 8.4232, cov_diff 3.50663546790203
# Epoch: 0, iteration 19, loss 2.6117, loss_f 9.9821, , loss_G 8.4232, cov_diff 3.2620319904089268
# Generator step
# Epoch: 0, iteration 20, loss 1.8913, loss_f 9.5725, , loss_G 2.8950, cov_diff 3.4817159392369135
# Epoch: 0, iteration 21, loss 6.7147, loss_f 11.5860, , loss_G 2.8950, cov_diff 2.4563218384324745
# Epoch: 0, iteration 22, loss 5.9802, loss_f 11.1135, , loss_G 2.8950, cov_diff 2.65089111086312
# Epoch: 0, iteration 23, loss 6.1176, loss_f 10.6231, , loss_G 2.8950, cov_diff 2.6287566320690856
# Epoch: 0, iteration 24, loss 6.7357, loss_f 10.6173, , loss_G 2.8950, cov_diff 2.550100458258314
# Generator step
# Epoch: 0, iteration 25, loss 5.5953, loss_f 10.2822, , loss_G -0.4542, cov_diff 2.7207336947755243
# Epoch: 0, iteration 26, loss 8.2992, loss_f 11.8716, , loss_G -0.4542, cov_diff 2.2492607990650355
# Epoch: 0, iteration 27, loss 8.4620, loss_f 11.4938, , loss_G -0.4542, cov_diff 2.233158217256293
# Epoch: 0, iteration 28, loss 8.3297, loss_f 11.6388, , loss_G -0.4542, cov_diff 2.011611170887674
# Epoch: 0, iteration 29, loss 8.4143, loss_f 11.2540, , loss_G -0.4542, cov_diff 2.0201211558925882
# Generator step
# Epoch: 0, iteration 30, loss 8.1874, loss_f 11.6663, , loss_G -2.3542, cov_diff 2.1545514033521793
# Epoch: 0, iteration 31, loss 9.5676, loss_f 12.5047, , loss_G -2.3542, cov_diff 1.9309187681563451
# Epoch: 0, iteration 32, loss 9.6301, loss_f 12.4579, , loss_G -2.3542, cov_diff 1.7893457776699975
# Epoch: 0, iteration 33, loss 10.0403, loss_f 11.9316, , loss_G -2.3542, cov_diff 1.7032176353890023
# Epoch: 0, iteration 34, loss 9.4925, loss_f 12.2545, , loss_G -2.3542, cov_diff 1.927845560484846
# Generator step
# Epoch: 0, iteration 35, loss 9.2027, loss_f 12.3184, , loss_G -3.0435, cov_diff 1.9031107347064686
# Epoch: 0, iteration 36, loss 11.4522, loss_f 12.9868, , loss_G -3.0435, cov_diff 1.293527510500342
# Epoch: 0, iteration 37, loss 10.7326, loss_f 13.1721, , loss_G -3.0435, cov_diff 1.4742409433725336
# Epoch: 0, iteration 38, loss 10.6212, loss_f 13.3927, , loss_G -3.0435, cov_diff 1.501068110469397
# Epoch: 0, iteration 39, loss 10.5257, loss_f 13.1557, , loss_G -3.0435, cov_diff 1.582289848075282
# Generator step
# Epoch: 0, iteration 40, loss 10.8605, loss_f 12.8467, , loss_G -4.4371, cov_diff 1.515491976348675
# Epoch: 0, iteration 41, loss 11.4568, loss_f 13.8002, , loss_G -4.4371, cov_diff 1.2461055467042645
# Epoch: 0, iteration 42, loss 11.2060, loss_f 13.8546, , loss_G -4.4371, cov_diff 1.406554601128801
# Epoch: 0, iteration 43, loss 11.4101, loss_f 13.6652, , loss_G -4.4371, cov_diff 1.2339110337309387
# Epoch: 0, iteration 44, loss 11.4522, loss_f 13.7072, , loss_G -4.4371, cov_diff 1.2399443455516217
# Generator step
# Epoch: 0, iteration 45, loss 11.3926, loss_f 13.6005, , loss_G -4.5924, cov_diff 1.232787024209439
# Epoch: 0, iteration 46, loss 12.1177, loss_f 14.3319, , loss_G -4.5924, cov_diff 1.0862617846983667
# Epoch: 0, iteration 47, loss 11.9620, loss_f 14.6770, , loss_G -4.5924, cov_diff 1.1663275824818307
# Epoch: 0, iteration 48, loss 11.7760, loss_f 14.4473, , loss_G -4.5924, cov_diff 1.1797108735855057
# Epoch: 0, iteration 49, loss 11.5457, loss_f 14.2884, , loss_G -4.5924, cov_diff 1.1487256485942845
# Generator step
# Epoch: 0, iteration 50, loss 11.7903, loss_f 14.4935, , loss_G -4.5436, cov_diff 1.1506549564716964
# Epoch: 0, iteration 51, loss 12.2497, loss_f 14.9172, , loss_G -4.5436, cov_diff 1.0370409133121896
# Epoch: 0, iteration 52, loss 12.5970, loss_f 15.0394, , loss_G -4.5436, cov_diff 0.9307966804811525
# Epoch: 0, iteration 53, loss 12.2258, loss_f 15.1590, , loss_G -4.5436, cov_diff 1.0039379865773104
# Epoch: 0, iteration 54, loss 12.2772, loss_f 14.8615, , loss_G -4.5436, cov_diff 1.0027746002445947
# Generator step
# Epoch: 0, iteration 55, loss 12.1394, loss_f 15.0362, , loss_G -4.6213, cov_diff 1.066992585538341
# Epoch: 0, iteration 56, loss 12.6566, loss_f 15.5753, , loss_G -4.6213, cov_diff 0.9547275426876896
# Epoch: 0, iteration 57, loss 12.9395, loss_f 15.5170, , loss_G -4.6213, cov_diff 0.928105629450918
# Epoch: 0, iteration 58, loss 13.0819, loss_f 15.2964, , loss_G -4.6213, cov_diff 0.87492467618941
# Epoch: 0, iteration 59, loss 12.9537, loss_f 15.6710, , loss_G -4.6213, cov_diff 0.8813681850576992
# Generator step
# Epoch: 0, iteration 60, loss 12.6887, loss_f 15.6614, , loss_G -4.8580, cov_diff 0.9127921744280186
# Epoch: 0, iteration 61, loss 13.3259, loss_f 16.1183, , loss_G -4.8580, cov_diff 0.8265706778608372
# Epoch: 0, iteration 62, loss 13.3677, loss_f 16.3425, , loss_G -4.8580, cov_diff 0.7941401973163972
# Epoch: 0, iteration 63, loss 13.1334, loss_f 16.3964, , loss_G -4.8580, cov_diff 0.8693593701410055
# Epoch: 0, iteration 64, loss 13.4044, loss_f 15.9928, , loss_G -4.8580, cov_diff 0.7893272344660666
# Generator step
# Epoch: 0, iteration 65, loss 13.3167, loss_f 16.0768, , loss_G -5.2783, cov_diff 0.826570359361153
# Epoch: 0, iteration 66, loss 13.6056, loss_f 16.4823, , loss_G -5.2783, cov_diff 0.7946043590628133
# Epoch: 0, iteration 67, loss 13.5523, loss_f 16.5378, , loss_G -5.2783, cov_diff 0.8542815645681759
# Epoch: 0, iteration 68, loss 13.7663, loss_f 16.7455, , loss_G -5.2783, cov_diff 0.7872253934514833
# Epoch: 0, iteration 69, loss 13.5202, loss_f 16.7079, , loss_G -5.2783, cov_diff 0.8072654036072656
# Generator step
# Epoch: 0, iteration 70, loss 13.5499, loss_f 16.4556, , loss_G -5.3221, cov_diff 0.7889062850397415
# Epoch: 0, iteration 71, loss 13.7810, loss_f 17.0723, , loss_G -5.3221, cov_diff 0.7555244430101041
# Epoch: 0, iteration 72, loss 13.8734, loss_f 17.0447, , loss_G -5.3221, cov_diff 0.7758891362861325
# Epoch: 0, iteration 73, loss 13.9176, loss_f 17.0542, , loss_G -5.3221, cov_diff 0.7713824331622057
# Epoch: 0, iteration 74, loss 13.9193, loss_f 17.2619, , loss_G -5.3221, cov_diff 0.7629191584976636
# Generator step
# Epoch: 0, iteration 75, loss 13.8989, loss_f 16.9934, , loss_G -5.4022, cov_diff 0.7683788828818676
# Epoch: 0, iteration 76, loss 14.3997, loss_f 17.7651, , loss_G -5.4022, cov_diff 0.763867644635798
# Epoch: 0, iteration 77, loss 14.2182, loss_f 17.3772, , loss_G -5.4022, cov_diff 0.7514226088328183
# Epoch: 0, iteration 78, loss 14.1055, loss_f 17.5005, , loss_G -5.4022, cov_diff 0.7418222062417691
# Epoch: 0, iteration 79, loss 14.3459, loss_f 17.7039, , loss_G -5.4022, cov_diff 0.7666863751147003
# Generator step
# Epoch: 0, iteration 80, loss 14.1526, loss_f 17.5542, , loss_G -5.3755, cov_diff 0.7651625722437413
# Epoch: 0, iteration 81, loss 14.2320, loss_f 17.9858, , loss_G -5.3755, cov_diff 0.7615138524241738
# Epoch: 0, iteration 82, loss 14.4536, loss_f 17.9103, , loss_G -5.3755, cov_diff 0.7650371271160191
# Epoch: 0, iteration 83, loss 14.4202, loss_f 17.7591, , loss_G -5.3755, cov_diff 0.7542702577485424
# Epoch: 0, iteration 84, loss 14.2537, loss_f 17.8341, , loss_G -5.3755, cov_diff 0.7610656367539916
# Generator step
# Epoch: 0, iteration 85, loss 14.5415, loss_f 17.9496, , loss_G -5.5667, cov_diff 0.7426855802807734
# Epoch: 0, iteration 86, loss 14.5852, loss_f 18.3493, , loss_G -5.5667, cov_diff 0.7607659755164773
# Epoch: 0, iteration 87, loss 14.5220, loss_f 18.1145, , loss_G -5.5667, cov_diff 0.7573973834058457
# Epoch: 0, iteration 88, loss 14.7497, loss_f 18.1043, , loss_G -5.5667, cov_diff 0.7573899305526581
# Epoch: 0, iteration 89, loss 14.6401, loss_f 18.0840, , loss_G -5.5667, cov_diff 0.745357493214703
# Generator step
# Epoch: 0, iteration 90, loss 14.6138, loss_f 18.0801, , loss_G -5.5738, cov_diff 0.7549783538781497
# Epoch: 0, iteration 91, loss 14.8750, loss_f 18.4924, , loss_G -5.5738, cov_diff 0.7594241792936702
# Epoch: 0, iteration 92, loss 14.8545, loss_f 18.3170, , loss_G -5.5738, cov_diff 0.7782037266150692
# Epoch: 0, iteration 93, loss 14.9002, loss_f 18.3430, , loss_G -5.5738, cov_diff 0.7699086991134002
# Epoch: 0, iteration 94, loss 14.6401, loss_f 18.4742, , loss_G -5.5738, cov_diff 0.7692605318414172
# Generator step
# Epoch: 0, iteration 95, loss 14.5385, loss_f 18.4002, , loss_G -5.3384, cov_diff 0.7691426963039005
# Epoch: 0, iteration 96, loss 14.7675, loss_f 18.4480, , loss_G -5.3384, cov_diff 0.7584248529926257
# Epoch: 0, iteration 97, loss 14.7762, loss_f 18.5646, , loss_G -5.3384, cov_diff 0.7613099227474893
# Epoch: 0, iteration 98, loss 14.6397, loss_f 18.6931, , loss_G -5.3384, cov_diff 0.7696686218112365
# Epoch: 0, iteration 99, loss 15.0414, loss_f 18.5030, , loss_G -5.3384, cov_diff 0.7635060962725039
# Generator step
# Epoch: 0, iteration 100, loss 14.8957, loss_f 18.7790, , loss_G -5.5062, cov_diff 0.7484928671808155
# Epoch: 0, iteration 101, loss 15.0804, loss_f 18.6325, , loss_G -5.5062, cov_diff 0.781087464752916
# Epoch: 0, iteration 102, loss 14.9791, loss_f 18.8429, , loss_G -5.5062, cov_diff 0.7832452903633081
# Epoch: 0, iteration 103, loss 15.0541, loss_f 18.7171, , loss_G -5.5062, cov_diff 0.7725777497663231
# Epoch: 0, iteration 104, loss 15.2958, loss_f 18.7059, , loss_G -5.5062, cov_diff 0.7663863771540996
# Generator step
# Epoch: 0, iteration 105, loss 14.9095, loss_f 18.7037, , loss_G -5.5577, cov_diff 0.7743844509596048
# Epoch: 0, iteration 106, loss 15.1341, loss_f 18.9289, , loss_G -5.5577, cov_diff 0.7785812328621127
# Epoch: 0, iteration 107, loss 15.1098, loss_f 19.2232, , loss_G -5.5577, cov_diff 0.7810755815978879
# Epoch: 0, iteration 108, loss 15.0908, loss_f 18.9306, , loss_G -5.5577, cov_diff 0.7787795954644086
# Epoch: 0, iteration 109, loss 15.0278, loss_f 18.9757, , loss_G -5.5577, cov_diff 0.7824123134607609
# Generator step
# Epoch: 0, iteration 110, loss 15.1065, loss_f 18.7100, , loss_G -5.7515, cov_diff 0.7995272225933453
# Epoch: 0, iteration 111, loss 14.9501, loss_f 19.1691, , loss_G -5.7515, cov_diff 0.7775503368551164
# Epoch: 0, iteration 112, loss 15.2087, loss_f 19.3112, , loss_G -5.7515, cov_diff 0.790498624748524
# Epoch: 0, iteration 113, loss 15.2831, loss_f 19.2514, , loss_G -5.7515, cov_diff 0.7996896037084548
# Epoch: 0, iteration 114, loss 15.0968, loss_f 19.1119, , loss_G -5.7515, cov_diff 0.7891612295520514
# Generator step
# Epoch: 0, iteration 115, loss 15.1216, loss_f 19.3336, , loss_G -5.4548, cov_diff 0.7845425716106535
# Epoch: 0, iteration 116, loss 15.2861, loss_f 19.2248, , loss_G -5.4548, cov_diff 0.8006913124129292
# Epoch: 0, iteration 117, loss 15.2795, loss_f 19.1774, , loss_G -5.4548, cov_diff 0.7988986293401894
# Epoch: 0, iteration 118, loss 15.1257, loss_f 19.2793, , loss_G -5.4548, cov_diff 0.7911716387073211
# Epoch: 0, iteration 119, loss 14.9717, loss_f 19.3104, , loss_G -5.4548, cov_diff 0.7848885191834434
# Generator step
# Epoch: 0, iteration 120, loss 15.1758, loss_f 19.1857, , loss_G -5.5830, cov_diff 0.7979984784833037
# Epoch: 0, iteration 121, loss 15.3413, loss_f 19.2336, , loss_G -5.5830, cov_diff 0.8017851518018352
# Epoch: 0, iteration 122, loss 15.1538, loss_f 19.4084, , loss_G -5.5830, cov_diff 0.8005144776753101
# Epoch: 0, iteration 123, loss 15.1890, loss_f 19.3411, , loss_G -5.5830, cov_diff 0.7939483900144336
# Epoch: 0, iteration 124, loss 15.2510, loss_f 19.4939, , loss_G -5.5830, cov_diff 0.8032729673054784
# Generator step
# Epoch: 0, iteration 125, loss 15.0687, loss_f 19.4043, , loss_G -5.3666, cov_diff 0.7876201640403222
# Epoch: 0, iteration 126, loss 15.3126, loss_f 19.4566, , loss_G -5.3666, cov_diff 0.8026974625253572
# Epoch: 0, iteration 127, loss 15.3021, loss_f 19.3624, , loss_G -5.3666, cov_diff 0.8001235728201416
# Epoch: 0, iteration 128, loss 15.1882, loss_f 19.5836, , loss_G -5.3666, cov_diff 0.7947853404411097
# Epoch: 0, iteration 129, loss 15.2233, loss_f 19.4684, , loss_G -5.3666, cov_diff 0.8089807153930118
# Generator step
# Epoch: 0, iteration 130, loss 15.3118, loss_f 19.5354, , loss_G -5.5441, cov_diff 0.8096361852607799
# Epoch: 0, iteration 131, loss 15.5459, loss_f 19.3594, , loss_G -5.5441, cov_diff 0.7991082359586563
# Epoch: 0, iteration 132, loss 15.4206, loss_f 19.6128, , loss_G -5.5441, cov_diff 0.8040538900179132
# Epoch: 0, iteration 133, loss 15.3462, loss_f 19.3848, , loss_G -5.5441, cov_diff 0.7978309063079669
# Epoch: 0, iteration 134, loss 15.3113, loss_f 19.6073, , loss_G -5.5441, cov_diff 0.8111123837308768
# Generator step
# Epoch: 0, iteration 135, loss 15.3872, loss_f 19.3474, , loss_G -5.7135, cov_diff 0.8120064174917871
# Epoch: 0, iteration 136, loss 15.4437, loss_f 19.5789, , loss_G -5.7135, cov_diff 0.8108943709765905
# Epoch: 0, iteration 137, loss 15.3266, loss_f 19.5301, , loss_G -5.7135, cov_diff 0.8111539899634195
# Epoch: 0, iteration 138, loss 15.3547, loss_f 19.5239, , loss_G -5.7135, cov_diff 0.801198920730286
# Epoch: 0, iteration 139, loss 15.4648, loss_f 19.6377, , loss_G -5.7135, cov_diff 0.8124247776556218
# Generator step
# Epoch: 0, iteration 140, loss 15.3718, loss_f 19.5762, , loss_G -5.5837, cov_diff 0.8145384756407106
# Epoch: 0, iteration 141, loss 15.5327, loss_f 19.4872, , loss_G -5.5837, cov_diff 0.8301987179904824
# Epoch: 0, iteration 142, loss 15.3982, loss_f 19.6457, , loss_G -5.5837, cov_diff 0.8145150799568291
# Epoch: 0, iteration 143, loss 15.4871, loss_f 19.6261, , loss_G -5.5837, cov_diff 0.8109671900779357
# Epoch: 0, iteration 144, loss 15.5037, loss_f 19.5656, , loss_G -5.5837, cov_diff 0.820927548781679
# Generator step
# Epoch: 0, iteration 145, loss 15.4378, loss_f 19.6427, , loss_G -5.6165, cov_diff 0.8161629623468182
# Epoch: 0, iteration 146, loss 15.5697, loss_f 19.8277, , loss_G -5.6165, cov_diff 0.8247494731426717
# Epoch: 0, iteration 147, loss 15.3479, loss_f 19.6976, , loss_G -5.6165, cov_diff 0.808694155279558
# Epoch: 0, iteration 148, loss 15.5735, loss_f 19.6293, , loss_G -5.6165, cov_diff 0.816413479579631
# Epoch: 0, iteration 149, loss 15.6337, loss_f 19.6739, , loss_G -5.6165, cov_diff 0.8181936913457462
# Generator step
# Epoch: 0, iteration 150, loss 15.2736, loss_f 19.6714, , loss_G -5.4379, cov_diff 0.8207028122803172
# Epoch: 0, iteration 151, loss 15.3929, loss_f 19.8626, , loss_G -5.4379, cov_diff 0.8069596290061537
# Epoch: 0, iteration 152, loss 15.5781, loss_f 19.7348, , loss_G -5.4379, cov_diff 0.8134753586736172
# Epoch: 0, iteration 153, loss 15.4821, loss_f 19.7386, , loss_G -5.4379, cov_diff 0.8233383866070677
# Epoch: 0, iteration 154, loss 15.6001, loss_f 19.7442, , loss_G -5.4379, cov_diff 0.8201254700839956
# Generator step
# Epoch: 0, iteration 155, loss 15.5374, loss_f 19.8387, , loss_G -5.6181, cov_diff 0.8242545373784743
# Epoch: 0, iteration 156, loss 15.4693, loss_f 19.7220, , loss_G -5.6181, cov_diff 0.8183031767239423
# Epoch: 0, iteration 157, loss 15.4316, loss_f 19.8950, , loss_G -5.6181, cov_diff 0.8210733166929076
# Epoch: 0, iteration 158, loss 15.3736, loss_f 19.8866, , loss_G -5.6181, cov_diff 0.8171287926294102
# Epoch: 0, iteration 159, loss 15.4411, loss_f 19.9541, , loss_G -5.6181, cov_diff 0.8172893957113169
# Generator step
# Epoch: 0, iteration 160, loss 15.5057, loss_f 19.7585, , loss_G -5.6264, cov_diff 0.8230730853427569
# Epoch: 0, iteration 161, loss 15.3989, loss_f 19.9314, , loss_G -5.6264, cov_diff 0.8238318995766929
# Epoch: 0, iteration 162, loss 15.5058, loss_f 19.8468, , loss_G -5.6264, cov_diff 0.8312146753107569
# Epoch: 0, iteration 163, loss 15.5878, loss_f 19.9069, , loss_G -5.6264, cov_diff 0.8265621012803062
# Epoch: 0, iteration 164, loss 15.5686, loss_f 19.9053, , loss_G -5.6264, cov_diff 0.8220783946966307
# Generator step
# Epoch: 0, iteration 165, loss 15.4896, loss_f 19.9924, , loss_G -5.4933, cov_diff 0.8294613723544408
# Epoch: 0, iteration 166, loss 15.5427, loss_f 19.8495, , loss_G -5.4933, cov_diff 0.8356265165271481
# Epoch: 0, iteration 167, loss 15.4895, loss_f 19.8959, , loss_G -5.4933, cov_diff 0.8268687627177169
# Epoch: 0, iteration 168, loss 15.5377, loss_f 19.8485, , loss_G -5.4933, cov_diff 0.820439058390367
# Epoch: 0, iteration 169, loss 15.4936, loss_f 19.8125, , loss_G -5.4933, cov_diff 0.8197040348793582
# Generator step
# Epoch: 0, iteration 170, loss 15.5070, loss_f 20.0221, , loss_G -5.4960, cov_diff 0.8177809009879734
# Epoch: 0, iteration 171, loss 15.2781, loss_f 19.9274, , loss_G -5.4960, cov_diff 0.8077251639184977
# Epoch: 0, iteration 172, loss 15.6096, loss_f 19.9124, , loss_G -5.4960, cov_diff 0.83150648407357
# Epoch: 0, iteration 173, loss 15.4812, loss_f 19.9446, , loss_G -5.4960, cov_diff 0.8215347419253678
# Epoch: 0, iteration 174, loss 15.4160, loss_f 19.8916, , loss_G -5.4960, cov_diff 0.803949940352444
# Generator step
# Epoch: 0, iteration 175, loss 15.6624, loss_f 19.9267, , loss_G -5.6990, cov_diff 0.8274115309185056
# Epoch: 0, iteration 176, loss 15.4992, loss_f 19.8409, , loss_G -5.6990, cov_diff 0.8190945107777413
# Epoch: 0, iteration 177, loss 15.5728, loss_f 19.9066, , loss_G -5.6990, cov_diff 0.81715502829118
# Epoch: 0, iteration 178, loss 15.5189, loss_f 19.9376, , loss_G -5.6990, cov_diff 0.8206419412984219
# Epoch: 0, iteration 179, loss 15.5358, loss_f 19.9568, , loss_G -5.6990, cov_diff 0.8286628374926956
# Generator step
# Epoch: 0, iteration 180, loss 15.5928, loss_f 19.9097, , loss_G -5.6380, cov_diff 0.8252739315741654
# Epoch: 0, iteration 181, loss 15.6745, loss_f 19.9396, , loss_G -5.6380, cov_diff 0.8306782059319523
# Epoch: 0, iteration 182, loss 15.5532, loss_f 19.9009, , loss_G -5.6380, cov_diff 0.8253563557667785
# Epoch: 0, iteration 183, loss 15.4279, loss_f 19.7603, , loss_G -5.6380, cov_diff 0.8184019931100255
# Epoch: 0, iteration 184, loss 15.5312, loss_f 19.9885, , loss_G -5.6380, cov_diff 0.8210264905945518
# Generator step
# Epoch: 0, iteration 185, loss 15.5935, loss_f 20.0101, , loss_G -5.5885, cov_diff 0.8286591611046964
# Epoch: 0, iteration 186, loss 15.5534, loss_f 20.0092, , loss_G -5.5885, cov_diff 0.8194010024777906
# Epoch: 0, iteration 187, loss 15.5493, loss_f 19.9433, , loss_G -5.5885, cov_diff 0.8194140377582656
# Epoch: 0, iteration 188, loss 15.6718, loss_f 19.8996, , loss_G -5.5885, cov_diff 0.8255380047890282
# Epoch: 0, iteration 189, loss 15.7085, loss_f 19.8627, , loss_G -5.5885, cov_diff 0.837351699525179
# Generator step
# Epoch: 0, iteration 190, loss 15.6330, loss_f 19.9472, , loss_G -5.6595, cov_diff 0.8315956828434659
# Epoch: 0, iteration 191, loss 15.5761, loss_f 20.0208, , loss_G -5.6595, cov_diff 0.8287794199436658
# Epoch: 0, iteration 192, loss 15.3861, loss_f 19.9015, , loss_G -5.6595, cov_diff 0.8189755198858774
# Epoch: 0, iteration 193, loss 15.3883, loss_f 19.8898, , loss_G -5.6595, cov_diff 0.8288895775697744
# Epoch: 0, iteration 194, loss 15.5553, loss_f 19.9580, , loss_G -5.6595, cov_diff 0.8238836651389936
# Generator step
# Epoch: 0, iteration 195, loss 15.5436, loss_f 19.8747, , loss_G -5.6063, cov_diff 0.8254996008736659
# Epoch: 0, iteration 196, loss 15.4904, loss_f 19.9935, , loss_G -5.6063, cov_diff 0.8250818674462245
# Epoch: 0, iteration 197, loss 15.5502, loss_f 19.9767, , loss_G -5.6063, cov_diff 0.8291274374180762
# Epoch: 0, iteration 198, loss 15.5128, loss_f 20.1199, , loss_G -5.6063, cov_diff 0.8285343965112281
# Epoch: 0, iteration 199, loss 15.5062, loss_f 19.8858, , loss_G -5.6063, cov_diff 0.8202283544030687
# Generator step
# Epoch: 0, iteration 200, loss 15.5854, loss_f 19.8321, , loss_G -5.6694, cov_diff 0.8340397899642388
# Epoch: 0, iteration 201, loss 15.4664, loss_f 19.8900, , loss_G -5.6694, cov_diff 0.8270522154798109
# Epoch: 0, iteration 202, loss 15.5194, loss_f 19.7838, , loss_G -5.6694, cov_diff 0.8294782103284296
# Epoch: 0, iteration 203, loss 15.4196, loss_f 19.9001, , loss_G -5.6694, cov_diff 0.8271923457976949
# Epoch: 0, iteration 204, loss 15.5500, loss_f 20.0060, , loss_G -5.6694, cov_diff 0.8231181526905726
# Generator step
# Epoch: 0, iteration 205, loss 15.6445, loss_f 19.9393, , loss_G -5.6748, cov_diff 0.8365436199628415
# Epoch: 0, iteration 206, loss 15.7797, loss_f 19.9857, , loss_G -5.6748, cov_diff 0.8323656660197228
# Epoch: 0, iteration 207, loss 15.6483, loss_f 19.9797, , loss_G -5.6748, cov_diff 0.8339117601397606
# Epoch: 0, iteration 208, loss 15.3531, loss_f 19.9360, , loss_G -5.6748, cov_diff 0.8328931711864734
# Epoch: 0, iteration 209, loss 15.5602, loss_f 19.9216, , loss_G -5.6748, cov_diff 0.833356733030859
# Generator step
# Epoch: 0, iteration 210, loss 15.6979, loss_f 19.8929, , loss_G -5.7514, cov_diff 0.8391058849535109
# Epoch: 0, iteration 211, loss 15.7044, loss_f 20.0119, , loss_G -5.7514, cov_diff 0.8348829609311577
# Epoch: 0, iteration 212, loss 15.6025, loss_f 20.0838, , loss_G -5.7514, cov_diff 0.8259763417164853
# Epoch: 0, iteration 213, loss 15.6501, loss_f 20.0581, , loss_G -5.7514, cov_diff 0.8379651516567416
# Epoch: 0, iteration 214, loss 15.4133, loss_f 20.0539, , loss_G -5.7514, cov_diff 0.8101831216435567
# Generator step
# Epoch: 0, iteration 215, loss 15.6890, loss_f 19.9430, , loss_G -5.7175, cov_diff 0.8362567179977302
# Epoch: 0, iteration 216, loss 15.7474, loss_f 19.9184, , loss_G -5.7175, cov_diff 0.8355500460666544
# Epoch: 0, iteration 217, loss 15.6724, loss_f 19.9599, , loss_G -5.7175, cov_diff 0.8302332797354872
# Epoch: 0, iteration 218, loss 15.4622, loss_f 19.9166, , loss_G -5.7175, cov_diff 0.8283346804635123
# Epoch: 0, iteration 219, loss 15.7006, loss_f 19.8940, , loss_G -5.7175, cov_diff 0.8309137570466916
# Generator step
# Epoch: 0, iteration 220, loss 15.5345, loss_f 19.7798, , loss_G -5.6446, cov_diff 0.8252222695294759
# Epoch: 0, iteration 221, loss 15.5873, loss_f 20.0146, , loss_G -5.6446, cov_diff 0.8193711275935893
# Epoch: 0, iteration 222, loss 15.4692, loss_f 20.0138, , loss_G -5.6446, cov_diff 0.8192788743264799
# Epoch: 0, iteration 223, loss 15.6590, loss_f 19.9698, , loss_G -5.6446, cov_diff 0.8284112572684381
# Epoch: 0, iteration 224, loss 15.6213, loss_f 19.9821, , loss_G -5.6446, cov_diff 0.8282728106186565
# Generator step
# Epoch: 0, iteration 225, loss 15.4083, loss_f 19.8736, , loss_G -5.4715, cov_diff 0.8213137639976893
# Epoch: 0, iteration 226, loss 15.4361, loss_f 19.9091, , loss_G -5.4715, cov_diff 0.8247189269897606
# Epoch: 0, iteration 227, loss 15.4762, loss_f 19.8502, , loss_G -5.4715, cov_diff 0.8254808598926459
# Epoch: 0, iteration 228, loss 15.5317, loss_f 19.8997, , loss_G -5.4715, cov_diff 0.8274676021220341
# Epoch: 0, iteration 229, loss 15.4445, loss_f 19.9963, , loss_G -5.4715, cov_diff 0.8203127649421513
# Generator step
# Epoch: 0, iteration 230, loss 15.6063, loss_f 19.8268, , loss_G -5.6929, cov_diff 0.8351255738979999
# Epoch: 0, iteration 231, loss 15.6236, loss_f 19.7845, , loss_G -5.6929, cov_diff 0.8315154869778286
# Epoch: 0, iteration 232, loss 15.7072, loss_f 19.9347, , loss_G -5.6929, cov_diff 0.8290437056569956
# Epoch: 0, iteration 233, loss 15.5945, loss_f 20.0087, , loss_G -5.6929, cov_diff 0.8247862559663055
# Epoch: 0, iteration 234, loss 15.4385, loss_f 19.8515, , loss_G -5.6929, cov_diff 0.8176304044783791
# Generator step
# Epoch: 0, iteration 235, loss 15.5461, loss_f 19.9965, , loss_G -5.5479, cov_diff 0.8143745876101915
# Epoch: 0, iteration 236, loss 15.4111, loss_f 19.8485, , loss_G -5.5479, cov_diff 0.8294720530263543
# Epoch: 0, iteration 237, loss 15.4994, loss_f 19.9027, , loss_G -5.5479, cov_diff 0.8263100577941792
# Epoch: 0, iteration 238, loss 15.4802, loss_f 19.8854, , loss_G -5.5479, cov_diff 0.8216612608353905
# Epoch: 0, iteration 239, loss 15.4466, loss_f 19.8921, , loss_G -5.5479, cov_diff 0.8290940282180539
# Generator step
# Epoch: 0, iteration 240, loss 15.2830, loss_f 19.8017, , loss_G -5.3821, cov_diff 0.8183731527666929
# Epoch: 0, iteration 241, loss 15.4589, loss_f 19.9382, , loss_G -5.3821, cov_diff 0.8308143114440328
# Epoch: 0, iteration 242, loss 15.4520, loss_f 19.9559, , loss_G -5.3821, cov_diff 0.8290336365776363
# Epoch: 0, iteration 243, loss 15.5679, loss_f 19.8948, , loss_G -5.3821, cov_diff 0.8311272410302563
# Epoch: 0, iteration 244, loss 15.6940, loss_f 20.0061, , loss_G -5.3821, cov_diff 0.8292038181323884
# Generator step
# Epoch: 0, iteration 245, loss 15.4688, loss_f 19.9727, , loss_G -5.4825, cov_diff 0.8360639228814171
# Epoch: 0, iteration 246, loss 15.4953, loss_f 19.7441, , loss_G -5.4825, cov_diff 0.832726463810857
# Epoch: 0, iteration 247, loss 15.5389, loss_f 19.8539, , loss_G -5.4825, cov_diff 0.822647844930501
# Epoch: 0, iteration 248, loss 15.4373, loss_f 19.9425, , loss_G -5.4825, cov_diff 0.8236174056772966
# Epoch: 0, iteration 249, loss 15.6776, loss_f 19.8111, , loss_G -5.4825, cov_diff 0.834954138645288
# Generator step
# Epoch: 0, iteration 250, loss 15.5227, loss_f 19.6602, , loss_G -5.6926, cov_diff 0.8313414282276615
# Epoch: 0, iteration 251, loss 15.4684, loss_f 19.8540, , loss_G -5.6926, cov_diff 0.827665594826471
# Epoch: 0, iteration 252, loss 15.7666, loss_f 19.7921, , loss_G -5.6926, cov_diff 0.8347281839965116
# Epoch: 0, iteration 253, loss 15.4394, loss_f 19.8471, , loss_G -5.6926, cov_diff 0.8238858752642438
# Epoch: 0, iteration 254, loss 15.4654, loss_f 19.7813, , loss_G -5.6926, cov_diff 0.8344566019599803
# Generator step
# Epoch: 0, iteration 255, loss 15.3555, loss_f 19.8562, , loss_G -5.4274, cov_diff 0.8158406103847974
# Epoch: 0, iteration 256, loss 15.6638, loss_f 19.7804, , loss_G -5.4274, cov_diff 0.8353407050496958
# Epoch: 0, iteration 257, loss 15.6590, loss_f 19.9031, , loss_G -5.4274, cov_diff 0.8273193921772466
# Epoch: 0, iteration 258, loss 15.5111, loss_f 19.9634, , loss_G -5.4274, cov_diff 0.8286516061187245
# Epoch: 0, iteration 259, loss 15.5266, loss_f 19.9189, , loss_G -5.4274, cov_diff 0.8211031321372453
# Generator step
# Epoch: 0, iteration 260, loss 15.4695, loss_f 19.8957, , loss_G -5.5217, cov_diff 0.8220348265648866
# Epoch: 0, iteration 261, loss 15.4488, loss_f 19.8438, , loss_G -5.5217, cov_diff 0.8214703035115724
# Epoch: 0, iteration 262, loss 15.6618, loss_f 19.9520, , loss_G -5.5217, cov_diff 0.8220165441924695
# Epoch: 0, iteration 263, loss 15.6194, loss_f 19.8660, , loss_G -5.5217, cov_diff 0.8186054341151073
# Epoch: 0, iteration 264, loss 15.4580, loss_f 19.8946, , loss_G -5.5217, cov_diff 0.8165959725331344
# Generator step
# Epoch: 0, iteration 265, loss 15.4903, loss_f 19.9145, , loss_G -5.5331, cov_diff 0.8213805190929574
# Epoch: 0, iteration 266, loss 15.7195, loss_f 19.8044, , loss_G -5.5331, cov_diff 0.8240247733494905
# Epoch: 0, iteration 267, loss 15.5620, loss_f 19.8771, , loss_G -5.5331, cov_diff 0.8275041265360884
# Epoch: 0, iteration 268, loss 15.5331, loss_f 19.8534, , loss_G -5.5331, cov_diff 0.8260950320672213
# Epoch: 0, iteration 269, loss 15.6127, loss_f 19.9150, , loss_G -5.5331, cov_diff 0.8249402396911022
# Generator step
# Epoch: 0, iteration 270, loss 15.5314, loss_f 19.9261, , loss_G -5.5684, cov_diff 0.8227461869968707
# Epoch: 0, iteration 271, loss 15.8003, loss_f 19.8062, , loss_G -5.5684, cov_diff 0.830742705742461
# Epoch: 0, iteration 272, loss 15.4059, loss_f 19.9351, , loss_G -5.5684, cov_diff 0.8100908266520498
# Epoch: 0, iteration 273, loss 15.6546, loss_f 19.8023, , loss_G -5.5684, cov_diff 0.8225261570922484
# Epoch: 0, iteration 274, loss 15.4604, loss_f 19.8891, , loss_G -5.5684, cov_diff 0.817493517757574
# Generator step
# Epoch: 0, iteration 275, loss 15.6108, loss_f 19.9921, , loss_G -5.6148, cov_diff 0.8199983393826786
# Epoch: 0, iteration 276, loss 15.6509, loss_f 19.9593, , loss_G -5.6148, cov_diff 0.8272075559157688
# Epoch: 0, iteration 277, loss 15.6204, loss_f 19.9203, , loss_G -5.6148, cov_diff 0.8184481986130555
# Epoch: 0, iteration 278, loss 15.4588, loss_f 19.7800, , loss_G -5.6148, cov_diff 0.8076770003903821
# Epoch: 0, iteration 279, loss 15.6756, loss_f 19.8105, , loss_G -5.6148, cov_diff 0.8200131065793499
# Generator step
# Epoch: 0, iteration 280, loss 15.5356, loss_f 19.8293, , loss_G -5.6209, cov_diff 0.8183855108249829
# Epoch: 0, iteration 281, loss 15.5576, loss_f 19.7980, , loss_G -5.6209, cov_diff 0.8176001027995154
# Epoch: 0, iteration 282, loss 15.4425, loss_f 19.9004, , loss_G -5.6209, cov_diff 0.817903297752665
# Epoch: 0, iteration 283, loss 15.6472, loss_f 19.8702, , loss_G -5.6209, cov_diff 0.8301751453617373
# Epoch: 0, iteration 284, loss 15.6395, loss_f 19.9125, , loss_G -5.6209, cov_diff 0.8311741702826004
# Generator step
# Epoch: 0, iteration 285, loss 15.6081, loss_f 19.7165, , loss_G -5.7498, cov_diff 0.8219283207093148
# Epoch: 0, iteration 286, loss 15.4172, loss_f 19.9495, , loss_G -5.7498, cov_diff 0.8145359140499179
# Epoch: 0, iteration 287, loss 15.5843, loss_f 20.0058, , loss_G -5.7498, cov_diff 0.8231320176935663
# Epoch: 0, iteration 288, loss 15.4485, loss_f 19.9076, , loss_G -5.7498, cov_diff 0.8176163590540043
# Epoch: 0, iteration 289, loss 15.5837, loss_f 19.9578, , loss_G -5.7498, cov_diff 0.8208283014512684
# Generator step
# Epoch: 0, iteration 290, loss 15.6989, loss_f 19.8385, , loss_G -5.7797, cov_diff 0.8305805988674753
# Epoch: 0, iteration 291, loss 15.4770, loss_f 19.9566, , loss_G -5.7797, cov_diff 0.8272475332391304
# Epoch: 0, iteration 292, loss 15.6258, loss_f 19.8031, , loss_G -5.7797, cov_diff 0.8304631856873631
# Epoch: 0, iteration 293, loss 15.3858, loss_f 19.8893, , loss_G -5.7797, cov_diff 0.8145473107228471
# Epoch: 0, iteration 294, loss 15.5917, loss_f 19.9758, , loss_G -5.7797, cov_diff 0.810684853996242
# Generator step
# Epoch: 0, iteration 295, loss 15.6340, loss_f 19.8600, , loss_G -5.7040, cov_diff 0.8243078833011876
# Epoch: 0, iteration 296, loss 15.7660, loss_f 19.8319, , loss_G -5.7040, cov_diff 0.8345862946853929
# Epoch: 0, iteration 297, loss 15.7377, loss_f 19.8507, , loss_G -5.7040, cov_diff 0.819412719131293
# Epoch: 0, iteration 298, loss 15.4450, loss_f 19.6684, , loss_G -5.7040, cov_diff 0.8187224045146538
# Epoch: 0, iteration 299, loss 15.7240, loss_f 19.7625, , loss_G -5.7040, cov_diff 0.8275802886408075
# Generator step
# Epoch: 0, iteration 300, loss 15.5334, loss_f 19.9478, , loss_G -5.5595, cov_diff 0.8218263913401934
# Epoch: 0, iteration 301, loss 15.5428, loss_f 19.7572, , loss_G -5.5595, cov_diff 0.8216188327720809
# Epoch: 0, iteration 302, loss 15.6049, loss_f 19.6634, , loss_G -5.5595, cov_diff 0.8335787461224248
# Epoch: 0, iteration 303, loss 15.5837, loss_f 19.8286, , loss_G -5.5595, cov_diff 0.8202548502092872
# Epoch: 0, iteration 304, loss 15.3966, loss_f 19.8109, , loss_G -5.5595, cov_diff 0.819627627735643
# Generator step
# Epoch: 0, iteration 305, loss 15.4849, loss_f 19.8160, , loss_G -5.5769, cov_diff 0.8157514696808348
# Epoch: 0, iteration 306, loss 15.5908, loss_f 19.7612, , loss_G -5.5769, cov_diff 0.8278243745930088
# Epoch: 0, iteration 307, loss 15.5432, loss_f 19.8513, , loss_G -5.5769, cov_diff 0.8167150294179163
# Epoch: 0, iteration 308, loss 15.4991, loss_f 19.6925, , loss_G -5.5769, cov_diff 0.830600395293781
# Epoch: 0, iteration 309, loss 15.5503, loss_f 19.7200, , loss_G -5.5769, cov_diff 0.8235478666080427
# Generator step
# Epoch: 0, iteration 310, loss 15.4267, loss_f 19.8394, , loss_G -5.5070, cov_diff 0.8224891746722521
# Epoch: 0, iteration 311, loss 15.3628, loss_f 19.7006, , loss_G -5.5070, cov_diff 0.8130195319988681
# Epoch: 0, iteration 312, loss 15.4960, loss_f 19.9116, , loss_G -5.5070, cov_diff 0.8112877154863772
# Epoch: 0, iteration 313, loss 15.7451, loss_f 19.8409, , loss_G -5.5070, cov_diff 0.8174894577833801
# Epoch: 0, iteration 314, loss 15.6689, loss_f 19.8662, , loss_G -5.5070, cov_diff 0.8284000891055268
# Generator step
# Epoch: 0, iteration 315, loss 15.6246, loss_f 19.8212, , loss_G -5.7140, cov_diff 0.8280656687418092
# Epoch: 0, iteration 316, loss 15.4592, loss_f 19.8274, , loss_G -5.7140, cov_diff 0.8171304408794794
# Epoch: 0, iteration 317, loss 15.5697, loss_f 19.8200, , loss_G -5.7140, cov_diff 0.8211200744412365
# Epoch: 0, iteration 318, loss 15.3291, loss_f 19.7989, , loss_G -5.7140, cov_diff 0.8216282966602703
# Epoch: 0, iteration 319, loss 15.4726, loss_f 19.7997, , loss_G -5.7140, cov_diff 0.813425525936643
# Generator step
# Epoch: 0, iteration 320, loss 15.5346, loss_f 19.6418, , loss_G -5.7137, cov_diff 0.8178538183038246
# Epoch: 0, iteration 321, loss 15.3830, loss_f 19.7497, , loss_G -5.7137, cov_diff 0.8030234461009257
# Epoch: 0, iteration 322, loss 15.5468, loss_f 19.7128, , loss_G -5.7137, cov_diff 0.8192740406907904
# Epoch: 0, iteration 323, loss 15.4744, loss_f 19.7327, , loss_G -5.7137, cov_diff 0.8214054803877158
# Epoch: 0, iteration 324, loss 15.5236, loss_f 19.7802, , loss_G -5.7137, cov_diff 0.8186402244456719
# Generator step
# Epoch: 0, iteration 325, loss 15.4424, loss_f 19.8936, , loss_G -5.4956, cov_diff 0.8190375353212722
# Epoch: 0, iteration 326, loss 15.2679, loss_f 19.8373, , loss_G -5.4956, cov_diff 0.8148417976616887
# Epoch: 0, iteration 327, loss 15.4355, loss_f 19.7463, , loss_G -5.4956, cov_diff 0.8160300631715551
# Epoch: 0, iteration 328, loss 15.5605, loss_f 19.7735, , loss_G -5.4956, cov_diff 0.8165003011893106
# Epoch: 0, iteration 329, loss 15.3074, loss_f 19.7136, , loss_G -5.4956, cov_diff 0.8034216166488667
# Generator step
# Epoch: 0, iteration 330, loss 15.5054, loss_f 19.7776, , loss_G -5.6166, cov_diff 0.8175575972675799
# Epoch: 0, iteration 331, loss 15.4954, loss_f 19.7214, , loss_G -5.6166, cov_diff 0.811283533555416
# Epoch: 0, iteration 332, loss 15.4317, loss_f 19.8984, , loss_G -5.6166, cov_diff 0.8106801602447128
# Epoch: 0, iteration 333, loss 15.5062, loss_f 19.7252, , loss_G -5.6166, cov_diff 0.8181846006617973
# Epoch: 0, iteration 334, loss 15.7787, loss_f 19.7336, , loss_G -5.6166, cov_diff 0.8290232263407077
# Generator step
# Epoch: 0, iteration 335, loss 15.5781, loss_f 19.5585, , loss_G -5.7988, cov_diff 0.8243848220361336
# Epoch: 0, iteration 336, loss 15.4537, loss_f 19.7277, , loss_G -5.7988, cov_diff 0.8173011237373231
# Epoch: 0, iteration 337, loss 15.5111, loss_f 19.7856, , loss_G -5.7988, cov_diff 0.8248361611032327
# Epoch: 0, iteration 338, loss 15.4262, loss_f 19.8151, , loss_G -5.7988, cov_diff 0.8127146684318721
# Epoch: 0, iteration 339, loss 15.3956, loss_f 19.7276, , loss_G -5.7988, cov_diff 0.8115241885027517
# Generator step
# Epoch: 0, iteration 340, loss 15.3434, loss_f 19.7979, , loss_G -5.4444, cov_diff 0.7962188025352378
# Epoch: 0, iteration 341, loss 15.4945, loss_f 19.5805, , loss_G -5.4444, cov_diff 0.8094742462024784
# Epoch: 0, iteration 342, loss 15.6000, loss_f 19.6798, , loss_G -5.4444, cov_diff 0.8154287273399035
# Epoch: 0, iteration 343, loss 15.6423, loss_f 19.6804, , loss_G -5.4444, cov_diff 0.8318915786353851
# Epoch: 0, iteration 344, loss 15.6251, loss_f 19.5502, , loss_G -5.4444, cov_diff 0.8233771168244878
# Generator step
# Epoch: 0, iteration 345, loss 15.4470, loss_f 19.6663, , loss_G -5.6138, cov_diff 0.818271991236072
# Epoch: 0, iteration 346, loss 15.5141, loss_f 19.5758, , loss_G -5.6138, cov_diff 0.8089657757795893
# Epoch: 0, iteration 347, loss 15.5692, loss_f 19.7247, , loss_G -5.6138, cov_diff 0.8251014613046754
# Epoch: 0, iteration 348, loss 15.4987, loss_f 19.5433, , loss_G -5.6138, cov_diff 0.8173352542456849
# Epoch: 0, iteration 349, loss 15.6528, loss_f 19.7513, , loss_G -5.6138, cov_diff 0.825459669828439
# Generator step
# Epoch: 0, iteration 350, loss 15.2062, loss_f 19.6003, , loss_G -5.4060, cov_diff 0.8025740767103599
# Epoch: 0, iteration 351, loss 15.3458, loss_f 19.5877, , loss_G -5.4060, cov_diff 0.7985446358600952
# Epoch: 0, iteration 352, loss 15.5013, loss_f 19.6829, , loss_G -5.4060, cov_diff 0.7970934928717627
# Epoch: 0, iteration 353, loss 15.2788, loss_f 19.7654, , loss_G -5.4060, cov_diff 0.8085025416014054
# Epoch: 0, iteration 354, loss 15.6327, loss_f 19.5158, , loss_G -5.4060, cov_diff 0.8284728032891939
# Generator step
# Epoch: 0, iteration 355, loss 15.2589, loss_f 19.6544, , loss_G -5.4317, cov_diff 0.8019358869489569
# Epoch: 0, iteration 356, loss 15.4477, loss_f 19.6413, , loss_G -5.4317, cov_diff 0.8064384746032828
# Epoch: 0, iteration 357, loss 15.3910, loss_f 19.6486, , loss_G -5.4317, cov_diff 0.8083880235762468
# Epoch: 0, iteration 358, loss 15.2330, loss_f 19.6673, , loss_G -5.4317, cov_diff 0.8109568155651807
# Epoch: 0, iteration 359, loss 15.6849, loss_f 19.7043, , loss_G -5.4317, cov_diff 0.8226192002020076
# Generator step
# Epoch: 0, iteration 360, loss 15.3281, loss_f 19.7182, , loss_G -5.4691, cov_diff 0.807855563243129
# Epoch: 0, iteration 361, loss 15.3625, loss_f 19.5883, , loss_G -5.4691, cov_diff 0.811267994886434
# Epoch: 0, iteration 362, loss 15.5437, loss_f 19.5941, , loss_G -5.4691, cov_diff 0.8141187195586077
# Epoch: 0, iteration 363, loss 15.4632, loss_f 19.7682, , loss_G -5.4691, cov_diff 0.8038394550135493
# Epoch: 0, iteration 364, loss 15.3566, loss_f 19.7654, , loss_G -5.4691, cov_diff 0.8112184610222636
# Generator step
# Epoch: 0, iteration 365, loss 15.4700, loss_f 19.5651, , loss_G -5.6874, cov_diff 0.823534257357884
# Epoch: 0, iteration 366, loss 15.4431, loss_f 19.5830, , loss_G -5.6874, cov_diff 0.8152146128181051
# Epoch: 0, iteration 367, loss 15.6074, loss_f 19.5974, , loss_G -5.6874, cov_diff 0.8218730063323543
# Epoch: 0, iteration 368, loss 15.4821, loss_f 19.5135, , loss_G -5.6874, cov_diff 0.8126515562384387
# Epoch: 0, iteration 369, loss 15.4081, loss_f 19.7145, , loss_G -5.6874, cov_diff 0.8186219783765947
# Generator step
# Epoch: 0, iteration 370, loss 15.4049, loss_f 19.5586, , loss_G -5.6256, cov_diff 0.7987143945591357
# Epoch: 0, iteration 371, loss 15.5937, loss_f 19.7605, , loss_G -5.6256, cov_diff 0.8173382664976889
# Epoch: 0, iteration 372, loss 15.3504, loss_f 19.5760, , loss_G -5.6256, cov_diff 0.8051549128577378
# Epoch: 0, iteration 373, loss 15.4853, loss_f 19.5857, , loss_G -5.6256, cov_diff 0.8132158090737794
# Epoch: 0, iteration 374, loss 15.5223, loss_f 19.5428, , loss_G -5.6256, cov_diff 0.8134642706096148
# Generator step
# Epoch: 0, iteration 375, loss 15.5392, loss_f 19.7189, , loss_G -5.6798, cov_diff 0.8047329503813644
# Epoch: 0, iteration 376, loss 15.3170, loss_f 19.4561, , loss_G -5.6798, cov_diff 0.7933807141400282
# Epoch: 0, iteration 377, loss 15.4600, loss_f 19.6896, , loss_G -5.6798, cov_diff 0.8022188323102044
# Epoch: 0, iteration 378, loss 15.4613, loss_f 19.5450, , loss_G -5.6798, cov_diff 0.8132661242416197
# Epoch: 0, iteration 379, loss 15.4383, loss_f 19.6382, , loss_G -5.6798, cov_diff 0.8043690040068544
# Generator step
# Epoch: 0, iteration 380, loss 15.5391, loss_f 19.6183, , loss_G -5.7300, cov_diff 0.8163258004197089
# Epoch: 0, iteration 381, loss 15.3292, loss_f 19.5451, , loss_G -5.7300, cov_diff 0.7951076167423946
# Epoch: 0, iteration 382, loss 15.2670, loss_f 19.5648, , loss_G -5.7300, cov_diff 0.8038196169213235
# Epoch: 0, iteration 383, loss 15.5847, loss_f 19.6260, , loss_G -5.7300, cov_diff 0.8080853372820999
# Epoch: 0, iteration 384, loss 15.5458, loss_f 19.6255, , loss_G -5.7300, cov_diff 0.8134965550334486
# Generator step
# Epoch: 0, iteration 385, loss 15.3958, loss_f 19.7497, , loss_G -5.5210, cov_diff 0.8029698387375084
# Epoch: 0, iteration 386, loss 15.5025, loss_f 19.5064, , loss_G -5.5210, cov_diff 0.7972639892150348
# Epoch: 0, iteration 387, loss 15.3659, loss_f 19.5205, , loss_G -5.5210, cov_diff 0.8162741047835358
# Epoch: 0, iteration 388, loss 15.2791, loss_f 19.5184, , loss_G -5.5210, cov_diff 0.8076948717234265
# Epoch: 0, iteration 389, loss 15.2881, loss_f 19.5194, , loss_G -5.5210, cov_diff 0.8009549780593743
# Generator step
# Epoch: 0, iteration 390, loss 13.3678, loss_f 17.8142, , loss_G -4.4607, cov_diff 0.8016442708651251

# %%
plt.figure()
accuracy_history = np.array(acc_cov_diff[:400])
iteration = min(20000, len(accuracy_history)*50)
step = 50
plt.clf()
plt.grid("on", "both")
idx = np.max(np.where(accuracy_history > 3.5))
plt.plot(np.arange(idx*50,iteration,step), accuracy_history[idx:], linewidth=2, color = 'red')
plt.plot(np.arange(iteration+1), np.zeros(iteration+1), linewidth=2, color = 'green')
